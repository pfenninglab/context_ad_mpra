# %%
import pandas as pd
df = pd.read_csv('read_counts_R1R2 /df_MPRA3_20231110_R1R2.csv',index_col="ID")

# %%
for i in df.columns:
    print(i)
# Out:
# Barcode_RC_Enhancer10_R1
# Barcode_RC_Enhancer10_R2
# Barcode_RC_Enhancer10_R2_R1
# Contributor
# RSID
# Type
# ZC100R-MPRA3-AP1134-26-Striatum
# ZC100R2-MPRA3-AP1134-26-Striatum
# ZC101R-MPRA3-AP1134-26-Hippocampus
# ZC101R2-MPRA3-AP1134-26-Hippocampus
# ZC102D1-MPRA3-AP1134misc-26
# ZC102D2-MPRA3-AP1134misc-26
# ZC103R-MPRA3-AP1120-26-Cortex
# ZC103R2-MPRA3-AP1120-26-Cortex
# ZC104R-MPRA3-AP1120-26-Striatum
# ZC104R2-MPRA3-AP1120-26-Striatum
# ZC105R-MPRA3-AP1120-26-Hippocampus
# ZC105R2-MPRA3-AP1120-26-Hippocampus
# ZC106D1-MPRA3-AP1120misc-26
# ZC106D2-MPRA3-AP1120misc-26
# ZC107R-MPRA3-AP1121-26-Cortex
# ZC107R2-MPRA3-AP1121-26-Cortex
# ZC108R-MPRA3-AP1121-26-Striatum
# ZC108R2-MPRA3-AP1121-26-Striatum
# ZC109R-MPRA3-AP1121-26-Hippocampus
# ZC109R2-MPRA3-AP1121-26-Hippocampus
# ZC110D1-MPRA3-AP1121misc-26
# ZC110D2-MPRA3-AP1121misc-26
# ZC111D-MPRA3-THP1mono-26-Naive
# ZC111R-MPRA3-THP1mono-26-Naive
# ZC112D-MPRA3-THP1mono-26-Naive
# ZC112R-MPRA3-THP1mono-26-Naive
# ...

# %%
Brain_columns = [
'ZC52R-MPRA3-AP1068-26-Striatum',
'ZC95R-MPRA3-AP1133-26-Cortex',
'ZC95R2-MPRA3-AP1133-26-Cortex',

'ZC96R-MPRA3-AP1133-26-Striatum',
'ZC96R2-MPRA3-AP1133-26-Striatum',

'ZC97R-MPRA3-AP1133-26-Hippocampus',
'ZC97R2-MPRA3-AP1133-26-Hippocampus',

'ZC99R-MPRA3-AP1134-26-Cortex',
'ZC99R2-MPRA3-AP1134-26-Cortex',

'ZC100R-MPRA3-AP1134-26-Striatum',
'ZC100R2-MPRA3-AP1134-26-Striatum',

'ZC101R-MPRA3-AP1134-26-Hippocampus',
'ZC101R2-MPRA3-AP1134-26-Hippocampus',

'ZC103R-MPRA3-AP1120-26-Cortex',
'ZC103R2-MPRA3-AP1120-26-Cortex',

'ZC104R-MPRA3-AP1120-26-Striatum',
'ZC104R2-MPRA3-AP1120-26-Striatum',

'ZC105R-MPRA3-AP1120-26-Hippocampus',
'ZC105R2-MPRA3-AP1120-26-Hippocampus',

'ZC107R-MPRA3-AP1121-26-Cortex',
'ZC107R2-MPRA3-AP1121-26-Cortex',

'ZC108R-MPRA3-AP1121-26-Striatum',
'ZC108R2-MPRA3-AP1121-26-Striatum',

'ZC109R-MPRA3-AP1121-26-Hippocampus',
'ZC109R2-MPRA3-AP1121-26-Hippocampus',

'ZC39R-MPRA3-AP1066-26-Cortex',
'ZC40R-MPRA3-AP1066-26-Striatum',
'ZC41R-MPRA3-AP1066-26-Hippocampus',
'ZC44R-MPRA3-AP1057-26-Striatum',
'ZC45R-MPRA3-AP1057-26-Hippocampus',
'ZC47R-MPRA3-AP1067-26-Cortex',
'ZC48R-MPRA3-AP1067-26-Striatum',
'ZC49R-MPRA3-AP1067-26-Hippocampus',
'ZC51R-MPRA3-AP1068-26-Cortex',

'ZC53R-MPRA3-AP1068-26-Hippocampus',

]


import seaborn as sns
sns.clustermap(df[Brain_columns].corr("spearman"),vmin=0)

# %%
HEK293T_columns = [
#"enhancer_id",
'ZC65R-MPRA3-HEK293T-26-Naive',  
'ZC66R-MPRA3-HEK293T-26-Naive',  
'ZC71R-MPRA3-HEK293T-26-Naive',  
'ZC76RCol-MPRA3-HEK293T-26-Naive',  
#'ZC76RAco-MPRA3-HEK293T-26-Naive',  
'ZC81R-MPRA3-HEK293T-26-Naive',  
'ZC65D-MPRA3-HEK293T-26-Naive', 
'ZC66D-MPRA3-HEK293T-26-Naive', 
'ZC71D-MPRA3-HEK293T-26-Naive', 
'ZC76D-MPRA3-HEK293T-26-Naive', 
'ZC81D-MPRA3-HEK293T-26-Naive', 
]
import seaborn as sns
#sns.clustermap(df[HEK293T_columns].corr("spearman"))
df[HEK293T_columns].to_csv("read_counts_R1R2/HEK293T_DNA_RNA.csv")

# %%
THP1_columns = [
'ZC82R-MPRA3-THP1mac-26-Naive',
'ZC83D-MPRA3-THP1mac-26-Naive',
'ZC83R-MPRA3-THP1mac-26-Naive',
'ZC84R-MPRA3-THP1mac-26-IFNB',
'ZC85R-MPRA3-THP1mac-26-IFNG',
'ZC86D-MPRA3-THP1mac-26-Naive',
'ZC86R-MPRA3-THP1mac-26-Naive',
'ZC87R-MPRA3-THP1mac-26-IFNB',
'ZC88R-MPRA3-THP1mac-26-IFNG',
'ZC89R-MPRA3-THP1mac-26-LPSIFNG',
'ZC90D-MPRA3-THP1mono-26-Naive',
'ZC90R-MPRA3-THP1mono-26-Naive',
'ZC91D-MPRA3-THP1mac-26-Naive',
'ZC91R-MPRA3-THP1mac-26-Naive',
'ZC92R-MPRA3-THP1mac-26-IFNB',
'ZC93R-MPRA3-THP1mac-26-IFNG',
'ZC94R-MPRA3-THP1mac-26-LPSIFNG',
'ZC60D-MPRA3-THP1mono-26-Naive',
'ZC60R-MPRA3-THP1mono-26-Naive',
'ZC61D-MPRA3-THP1mac-26-Naive',
'ZC61R-MPRA3-THP1mac-26-Naive',
'ZC62R-MPRA3-THP1mac-26-IFNB',
'ZC63R-MPRA3-THP1mac-26-IFNG',
'ZC55R-MPRA3-THP1mac-26-Naive',
'ZC56R-MPRA3-THP1mac-26-Naive',
'ZC57D-MPRA3-THP1macDeadCells-26-Naive',
'ZC57R-MPRA3-THP1mac-26-Naive',
'ZC58R-MPRA3-THP1mac-26-IFNB',
'ZC59R-MPRA3-THP1mac-26-IFNG',
'ZC37R-MPRA3-THP1mono-26-Naive',
'ZC125D-MPRA3-THP1mac-26-LPSIFNG',
'ZC125R-MPRA3-THP1mac-26-LPSIFNG',
'ZC111D-MPRA3-THP1mono-26-Naive',
'ZC111R-MPRA3-THP1mono-26-Naive',
'ZC112D-MPRA3-THP1mono-26-Naive',
'ZC112R-MPRA3-THP1mono-26-Naive',
'ZC113D-MPRA3-THP1mono-26-Naive',
'ZC113R-MPRA3-THP1mono-26-Naive',
'ZC114D-MPRA3-THP1mac-26-LPSIFNG',
'ZC114R-MPRA3-THP1mac-26-LPSIFNG',
'ZC115D-MPRA3-THP1mac-26-LPSIFNG',
'ZC115R-MPRA3-THP1mac-26-LPSIFNG',
]
import seaborn as sns
sns.clustermap(df[THP1_columns].corr("spearman"))
df[THP1_columns].to_csv("read_counts_R1R2/THP1_DNA_RNA.csv")

# %%
import pandas as pd
df = pd.read_csv('read_counts_R2only/df_MPRA3_20231108_R2.csv',index_col="ID")
HMC3_columns = [
'ZC22-24D-MPRA3-HMC3-26-Stim',
'ZC22R-MPRA3-HMC3-26-IFNB',
'ZC23R-MPRA3-HMC3-26-IFNG',
'ZC24R-MPRA3-HMC3-26-LPSIFNG',
#'ZC25D-MPRA3-HMC3-26-LPSIFNG',
#'ZC25R-MPRA3-HMC3-26-LPSIFNG',
'ZC2D-MPRA3-HMC3-26-Naive',
'ZC2R-MPRA3-HMC3-26-Naive',
'ZC3-5D-MPRA3-HMC3-26-Stim',
'ZC3R-MPRA3-HMC3-26-Naive',
'ZC4R-MPRA3-HMC3-26-IFNB',
'ZC5R-MPRA3-HMC3-26-IFNG',
'ZC67D-MPRA3-HMC3-26-Naive',
'ZC67R-MPRA3-HMC3-26-Naive',
'ZC68R-MPRA3-HMC3-26-IFNG',
'ZC69R-MPRA3-HMC3-26-IFNB',
'ZC70R-MPRA3-HMC3-26-LPSIFNG',
'ZC72D-MPRA3-HMC3-26-Naive',
'ZC72RAco-MPRA3-HMC3-26-Naive',
'ZC72RCol-MPRA3-HMC3-26-Naive',
'ZC73RAco-MPRA3-HMC3-26-IFNG',
'ZC73RCol-MPRA3-HMC3-26-IFNG',
'ZC74RAco-MPRA3-HMC3-26-IFNB',
'ZC74RCol-MPRA3-HMC3-26-IFNB',
'ZC75RAco-MPRA3-HMC3-26-LPSIFNG',
'ZC75RCol-MPRA3-HMC3-26-LPSIFNG',
'ZC77D-MPRA3-HMC3-26-Naive',
'ZC77R-MPRA3-HMC3-26-Naive',
'ZC78R-MPRA3-HMC3-26-IFNG',
'ZC79R-MPRA3-HMC3-26-IFNB',
'ZC80R-MPRA3-HMC3-26-LPSIFNG',
]
import seaborn as sns
sns.clustermap(df[HMC3_columns].corr("spearman"))
df[HMC3_columns].to_csv("read_counts_R2only/HMC3_DNA_RNA.csv")
# Out:
# /tmp/ipykernel_34291/579040247.py:2: DtypeWarning: Columns (164) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('read_counts_R2only/df_MPRA3_20231108_R2.csv',index_col="ID")

# %%
HMC3_columns = [
'ZC22-24D-MPRA3-HMC3-26-Stim',
'ZC22R-MPRA3-HMC3-26-IFNB',
'ZC23R-MPRA3-HMC3-26-IFNG',
'ZC24R-MPRA3-HMC3-26-LPSIFNG',
#'ZC25D-MPRA3-HMC3-26-LPSIFNG',
#'ZC25R-MPRA3-HMC3-26-LPSIFNG',
'ZC2D-MPRA3-HMC3-26-Naive',
'ZC2R-MPRA3-HMC3-26-Naive',
'ZC3-5D-MPRA3-HMC3-26-Stim',
'ZC3R-MPRA3-HMC3-26-Naive',
'ZC4R-MPRA3-HMC3-26-IFNB',
'ZC5R-MPRA3-HMC3-26-IFNG',
'ZC67D-MPRA3-HMC3-26-Naive',
'ZC67R-MPRA3-HMC3-26-Naive',
'ZC68R-MPRA3-HMC3-26-IFNG',
'ZC69R-MPRA3-HMC3-26-IFNB',
'ZC70R-MPRA3-HMC3-26-LPSIFNG',
'ZC72D-MPRA3-HMC3-26-Naive',
'ZC72RAco-MPRA3-HMC3-26-Naive',
'ZC72RCol-MPRA3-HMC3-26-Naive',
'ZC73RAco-MPRA3-HMC3-26-IFNG',
'ZC73RCol-MPRA3-HMC3-26-IFNG',
'ZC74RAco-MPRA3-HMC3-26-IFNB',
'ZC74RCol-MPRA3-HMC3-26-IFNB',
'ZC75RAco-MPRA3-HMC3-26-LPSIFNG',
'ZC75RCol-MPRA3-HMC3-26-LPSIFNG',
'ZC77D-MPRA3-HMC3-26-Naive',
'ZC77R-MPRA3-HMC3-26-Naive',
'ZC78R-MPRA3-HMC3-26-IFNG',
'ZC79R-MPRA3-HMC3-26-IFNB',
'ZC80R-MPRA3-HMC3-26-LPSIFNG',
]
import seaborn as sns
sns.clustermap(df[HMC3_columns].corr("spearman"))
df[HMC3_columns].to_csv("read_counts_R1R2/HMC3_DNA_RNA.csv")

# %%
Brain_columns = [
'ZC100R-MPRA3-AP1134-26-Striatum',
'ZC100R2-MPRA3-AP1134-26-Striatum',
'ZC101R-MPRA3-AP1134-26-Hippocampus',
'ZC101R2-MPRA3-AP1134-26-Hippocampus',
'ZC102D1-MPRA3-AP1134misc-26',
'ZC102D2-MPRA3-AP1134misc-26',
'ZC103R-MPRA3-AP1120-26-Cortex',
'ZC103R2-MPRA3-AP1120-26-Cortex',
'ZC104R-MPRA3-AP1120-26-Striatum',
'ZC104R2-MPRA3-AP1120-26-Striatum',
'ZC105R-MPRA3-AP1120-26-Hippocampus',
'ZC105R2-MPRA3-AP1120-26-Hippocampus',
'ZC106D1-MPRA3-AP1120misc-26',
'ZC106D2-MPRA3-AP1120misc-26',
'ZC107R-MPRA3-AP1121-26-Cortex',
'ZC107R2-MPRA3-AP1121-26-Cortex',
'ZC108R-MPRA3-AP1121-26-Striatum',
'ZC108R2-MPRA3-AP1121-26-Striatum',
'ZC109R-MPRA3-AP1121-26-Hippocampus',
'ZC109R2-MPRA3-AP1121-26-Hippocampus',
'ZC110D1-MPRA3-AP1121misc-26',
'ZC110D2-MPRA3-AP1121misc-26',
'ZC39R-MPRA3-AP1066-26-Cortex',

'ZC40R-MPRA3-AP1066-26-Striatum',
'ZC41R-MPRA3-AP1066-26-Hippocampus',
'ZC42D1-MPRA3-AP1066misc-26',
'ZC42D2-MPRA3-AP1066misc-26',
'ZC44R-MPRA3-AP1057-26-Striatum',
'ZC45R-MPRA3-AP1057-26-Hippocampus',
'ZC46D1-MPRA3-AP1057misc-26',
'ZC46D2-MPRA3-AP1057misc-26',
'ZC47R-MPRA3-AP1067-26-Cortex',
'ZC48R-MPRA3-AP1067-26-Striatum',
'ZC49R-MPRA3-AP1067-26-Hippocampus',

'ZC50D1-MPRA3-AP1067misc-26',
'ZC50D2-MPRA3-AP1067misc-26',
'ZC51R-MPRA3-AP1068-26-Cortex',
'ZC52R-MPRA3-AP1068-26-Striatum',
'ZC53R-MPRA3-AP1068-26-Hippocampus',
'ZC54D1-MPRA3-AP1068misc-26',
'ZC54D2-MPRA3-AP1068misc-26',

'ZC95R-MPRA3-AP1133-26-Cortex',
'ZC95R2-MPRA3-AP1133-26-Cortex',
'ZC96R-MPRA3-AP1133-26-Striatum',
'ZC96R2-MPRA3-AP1133-26-Striatum',
'ZC97R-MPRA3-AP1133-26-Hippocampus',
'ZC97R2-MPRA3-AP1133-26-Hippocampus',
'ZC98D1-MPRA3-AP1133misc-26',
'ZC98D2-MPRA3-AP1133misc-26',
'ZC99R-MPRA3-AP1134-26-Cortex',
'ZC99R2-MPRA3-AP1134-26-Cortex']
df[Brain_columns].sort_index(axis=1).to_csv("read_counts_R1R2/Brain_DNA_RNA.csv")
import seaborn as sns
sns.clustermap(df[Brain_columns].corr("spearman"))
