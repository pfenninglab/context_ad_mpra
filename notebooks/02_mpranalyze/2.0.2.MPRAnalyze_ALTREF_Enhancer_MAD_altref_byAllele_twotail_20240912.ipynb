# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores))
bpparam <- MulticoreParam(num_cores, log = TRUE, stop.on.error = FALSE)

# %% [markdown]
# Load experiment

# %%
df_DNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele, 
                            rnaDesign = ~ Animal+Tissue
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_Brain.csv")
################################################################################################################################################################################################
df_DNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_Striatum_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_Striatum_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_Striatum_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele, 
                            rnaDesign = ~ Animal
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_Brain_Striatum.csv")


df_DNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_Cortex_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_Cortex_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_Cortex_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele, 
                            rnaDesign = ~ Animal
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_Brain_Cortex.csv")


df_DNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_Hippocampus_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_Hippocampus_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_Hippocampus_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:36:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:37:01.044812
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   8.531   0.409   9.375
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6186562 330.4   11607695 620.0 10205950 545.1
# Vcells 11187613  85.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:36:43] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID-

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele, 
                            rnaDesign = ~ Animal+Tissue
                            )
alpha <- getAlpha(obj, by.factor = "Tissue")
for (col_names in names(alpha)){   
    result <- testEmpirical(obj = obj,statistic = alpha[,col_names])
    row.names(result)<-row.names(alpha)
    write.csv(result, paste("enhancer_activities/MAD_TwoTail_NoControl/20240824_MAD_",col_names,".csv",sep=""))}
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:37:14.603727
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.181   0.408  12.657
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6168257 329.5   11607695 620.0 10205950 545.1
# Vcells 11210493  85.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:01] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:37:15.450515
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.314   0.425  13.093
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180284 330.1   11607695 620.0 10205950 545.1
# Vcells 11284379  86.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:02] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:37:15.903181
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.209   0.412  12.756
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180295 330.1   11607695 620.0 10205950 545.1
# Vcells 11284402  86.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:02] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:37:16.271462
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.249   0.412  12.754
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180306 330.1   11607695 620.0 10205950 545.1
# Vcells 11284429  86.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:02] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:37:16.634654
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  11.169   0.443  12.963
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180317 330.1   11607695 620.0 10205950 545.1
# Vcells 11284452  86.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:02] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:37:16.99539
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.259   0.384  12.890
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180329 330.1   11607695 620.0 10205950 545.1
# Vcells 11284477  86.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:01] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task:
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183852 330.3   11607695 620.0 10205950 545.1
# Vcells 11304410  86.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:01] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:37:23.436202
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.107   0.570  13.641
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183846 330.3   11607695 620.0 10205950 545.1
# Vcells 11304034  86.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:02] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/THP1Macrophage_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1Macrophage_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1Macrophage_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ Tissue
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_THP1Macrophage.csv")

#############################################################################################################################################

df_DNA <- read.csv("read_counts_R1R2/THP1Macrophage_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1Macrophage_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1Macrophage_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ Tissue
                            )

alpha <- getAlpha(obj, by.factor = "Tissue")
for (col_names in names(alpha)){   
    result <- testEmpirical(obj = obj,statistic = alpha[,col_names])
    row.names(result)<-row.names(alpha)
    write.csv(result, paste("enhancer_activities/MAD_TwoTail_NoControl/20240824_MAD_",col_names,".csv",sep=""))}
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:40:39.327389
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 187.045   1.496 193.868
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6169140 329.5   11607695 620.0 10205950 545.1
# Vcells 12184143  93.0   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:40:54.029306
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 205.467   1.073 209.068
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6169822 329.6   11607695 620.0 10205950 545.1
# Vcells 12192975  93.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 17
# Timestamp: 2024-09-12 15:40:56.459172
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 206.100   1.009 211.483
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6170507 329.6   11607695 620.0 10205950 545.1
# Vcells 12201813  93.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:40:57.088107
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 206.785   1.148 211.675
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6171867 329.7   11607695 620.0 10205950 545.1
# Vcells 12219478  93.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:40:57.701342
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.934   1.274 211.681
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6171877 329.7   11607695 620.0 10205950 545.1
# Vcells 12219493  93.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:40:58.356284
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.929   1.272 212.629
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173236 329.7   11607695 620.0 10205950 545.1
# Vcells 12237146  93.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:40:59.007456
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.402   1.470 212.439
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173247 329.7   11607695 620.0 10205950 545.1
# Vcells 12237170  93.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:40:59.549105
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.922   1.369 213.003
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6176629 329.9   11607695 620.0 10205950 545.1
# Vcells 12281285  93.7   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:41:00.043683
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.513   1.323 214.049
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6176640 329.9   11607695 620.0 10205950 545.1
# Vcells 12281308  93.7   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 15
# Timestamp: 2024-09-12 15:41:00.47333
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 208.340   1.166 214.047
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6176650 329.9   11607695 620.0 10205950 545.1
# Vcells 12281323  93.7   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:41:00.879565
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 206.665   1.503 213.673
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6176661 329.9   11607695 620.0 10205950 545.1
# Vcells 12281346  93.7   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:41:01.279845
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 201.690   2.153 214.100
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6176672 329.9   11607695 620.0 10205950 545.1
# Vcells 12281370  93.7   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:41:01.674456
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 209.398   1.339 214.792
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182076 330.2   11607695 620.0 10205950 545.1
# Vcells 12351922  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:41:02.08149
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.453   1.818 214.336
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182087 330.2   11607695 620.0 10205950 545.1
# Vcells 12351945  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:41:02.462501
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 210.256   0.635 214.700
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182099 330.2   11607695 620.0 10205950 545.1
# Vcells 12351970  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:41:02.84262
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 208.092   1.171 215.068
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182106 330.2   11607695 620.0 10205950 545.1
# Vcells 12351862  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:41:03.216406
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.635   1.314 215.223
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182115 330.2   11607695 620.0 10205950 545.1
# Vcells 12351820  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:41:03.592602
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.829   1.171 214.919
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182124 330.2   11607695 620.0 10205950 545.1
# Vcells 12351770  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 12
# Timestamp: 2024-09-12 15:41:03.968292
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 208.453   1.273 215.436
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182135 330.2   11607695 620.0 10205950 545.1
# Vcells 12351794  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:41:04.338823
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 210.108   1.211 215.522
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6182146 330.2   11607695 620.0 10205950 545.1
# Vcells 12351819  94.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 7
# Timestamp: 2024-09-12 15:41:04.701743
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 208.794   1.868 218.770
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184854 330.4   11607695 620.0 10205950 545.1
# Vcells 12387111  94.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:41:05.066152
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.495   1.333 216.510
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184865 330.4   11607695 620.0 10205950 545.1
# Vcells 12387135  94.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:41:05.424429
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 206.455   2.345 219.066
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184876 330.4   11607695 620.0 10205950 545.1
# Vcells 12387159  94.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:41:05.785288
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 209.340   1.268 217.921
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184843 330.4   11607695 620.0 10205950 545.1
# Vcells 12385925  94.5   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:37:24] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!
#
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:44:20.817401
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 186.583   0.847 192.678
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6169981 329.6   11607695 620.0 10205950 545.1
# Vcells 12185803  93.0   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:44:32.995521
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 199.927   0.715 205.259
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6170669 329.6   11607695 620.0 10205950 545.1
# Vcells 12194645  93.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 17
# Timestamp: 2024-09-12 15:44:36.432235
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 202.660   0.778 208.782
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6171354 329.6   11607695 620.0 10205950 545.1
# Vcells 12203484  93.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:44:37.328215
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 205.701   0.733 209.695
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6172039 329.7   11607695 620.0 10205950 545.1
# Vcells 12212326  93.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:44:37.97819
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 203.941   0.880 209.491
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173399 329.7   11607695 620.0 10205950 545.1
# Vcells 12229987  93.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:44:38.625582
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 205.489   0.733 210.002
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173409 329.7   11607695 620.0 10205950 545.1
# Vcells 12230002  93.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:44:39.281295
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.316   0.830 211.056
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6174094 329.8   11607695 620.0 10205950 545.1
# Vcells 12238840  93.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:44:39.941436
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.554   0.664 211.978
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175453 329.9   11607695 620.0 10205950 545.1
# Vcells 12256502  93.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:44:40.591737
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.393   0.771 211.907
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175464 329.9   11607695 620.0 10205950 545.1
# Vcells 12256525  93.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:44:41.097163
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 206.225   0.773 212.773
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178171 330.0   11607695 620.0 10205950 545.1
# Vcells 12291809  93.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:44:41.61559
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 205.104   1.330 212.982
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178182 330.0   11607695 620.0 10205950 545.1
# Vcells 12291832  93.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 15
# Timestamp: 2024-09-12 15:44:42.113163
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 203.541   1.339 212.847
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178193 330.0   11607695 620.0 10205950 545.1
# Vcells 12291855  93.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:44:42.541057
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.768   0.704 212.383
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178204 330.0   11607695 620.0 10205950 545.1
# Vcells 12291879  93.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 7
# Timestamp: 2024-09-12 15:44:42.948403
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 209.461   0.803 214.915
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183608 330.3   11607695 620.0 10205950 545.1
# Vcells 12362431  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:44:43.345211
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 207.648   0.870 214.435
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183619 330.3   11607695 620.0 10205950 545.1
# Vcells 12362454  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:44:43.725415
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 209.635   0.784 214.217
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183630 330.3   11607695 620.0 10205950 545.1
# Vcells 12362478  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:44:44.091676
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 208.355   0.771 213.884
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183641 330.3   11607695 620.0 10205950 545.1
# Vcells 12362502  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:44:44.444767
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 209.895   0.617 213.805
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183651 330.3   11607695 620.0 10205950 545.1
# Vcells 12362518  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:44:44.79464
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.129   1.041 213.829
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183662 330.3   11607695 620.0 10205950 545.1
# Vcells 12362542  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 12
# Timestamp: 2024-09-12 15:44:45.149574
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 206.953   0.850 214.873
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183673 330.3   11607695 620.0 10205950 545.1
# Vcells 12362566  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:44:45.502032
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 208.487   0.776 214.357
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183684 330.3   11607695 620.0 10205950 545.1
# Vcells 12362591  94.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:44:45.858404
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 205.065   1.828 216.254
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185705 330.4   11607695 620.0 10205950 545.1
# Vcells 12388608  94.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:44:46.215375
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.575   1.753 215.768
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185715 330.4   11607695 620.0 10205950 545.1
# Vcells 12388566  94.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:44:46.573004
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 204.755   1.786 216.498
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185690 330.4   11607695 620.0 10205950 545.1
# Vcells 12387596  94.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:41:07] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/HEK293T_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HEK293T_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HEK293T_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_HEK293T.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:45:14.076747
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.785   0.385  26.198
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6168517 329.5   11607695 620.0 10205950 545.1
# Vcells 11269374  86.0   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:45:15.167577
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  26.355   0.355  27.601
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173162 329.7   11607695 620.0 10205950 545.1
# Vcells 11319873  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:45:15.857633
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  26.333   0.343  27.290
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173173 329.7   11607695 620.0 10205950 545.1
# Vcells 11319896  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:45:16.373269
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  26.664   0.347  27.636
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173184 329.7   11607695 620.0 10205950 545.1
# Vcells 11319923  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:45:16.795901
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  26.545   0.410  27.600
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173195 329.7   11607695 620.0 10205950 545.1
# Vcells 11319947  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:45:17.179627
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184166 330.3   11607695 620.0 10205950 545.1
# Vcells 11436054  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:45:23.20088
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  26.598   0.406  28.331
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184177 330.3   11607695 620.0 10205950 545.1
# Vcells 11436078  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:45:23.558065
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  27.737   0.356  28.577
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184139 330.3   11607695 620.0 10205950 545.1
# Vcells 11434590  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:44:47] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/HMC3_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_barcodes_interaction.csv", header=TRUE,row.names=1)
df_DNA <- df_DNA[, !grepl("ZC23", colnames(df_DNA))]
df_RNA <- df_RNA[, !grepl("ZC23", colnames(df_RNA))]
annot_DNA <- annot_DNA[!grepl("ZC23", rownames(annot_DNA)), ]
df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)


#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ Tissue
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_HMC3.csv")


df_DNA <- read.csv("read_counts_R1R2/HMC3_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_barcodes_interaction.csv", header=TRUE,row.names=1)
df_DNA <- df_DNA[, !grepl("ZC23", colnames(df_DNA))]
df_RNA <- df_RNA[, !grepl("ZC23", colnames(df_RNA))]
annot_DNA <- annot_DNA[!grepl("ZC23", rownames(annot_DNA)), ]
df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)


#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ Tissue
                            )
alpha <- getAlpha(obj, by.factor = "Tissue")
for (col_names in names(alpha)){   
    result <- testEmpirical(obj = obj,statistic = alpha[,col_names])
    row.names(result)<-row.names(alpha)
    write.csv(result, paste("enhancer_activities/MAD_TwoTail_NoControl/20240912_MAD_",col_names,".csv",sep=""))}
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:47:28.658612
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 120.233   0.695 123.313
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6169437 329.5   11607695 620.0 10205950 545.1
# Vcells 11930972  91.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:47:36.069929
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 127.435   0.611 131.271
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6170116 329.6   11607695 620.0 10205950 545.1
# Vcells 11939469  91.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:47:37.548845
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.017   0.777 132.477
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6170801 329.6   11607695 620.0 10205950 545.1
# Vcells 11947977  91.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:47:38.300736
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.545   0.637 133.010
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6172835 329.7   11607695 620.0 10205950 545.1
# Vcells 11973461  91.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:47:38.898991
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.355   0.594 132.843
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6172845 329.7   11607695 620.0 10205950 545.1
# Vcells 11973418  91.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 17
# Timestamp: 2024-09-12 15:47:39.444552
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.320   0.735 133.247
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6172856 329.7   11607695 620.0 10205950 545.1
# Vcells 11973441  91.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:47:39.981812
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.432   0.696 134.554
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180282 330.1   11607695 620.0 10205950 545.1
# Vcells 12066807  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:47:40.413484
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.554   0.639 134.533
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180293 330.1   11607695 620.0 10205950 545.1
# Vcells 12066839  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:47:40.791364
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.447   0.667 134.747
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180304 330.1   11607695 620.0 10205950 545.1
# Vcells 12066863  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 7
# Timestamp: 2024-09-12 15:47:41.162169
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.410   0.751 133.282
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180315 330.1   11607695 620.0 10205950 545.1
# Vcells 12066887  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:47:41.533699
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.953   0.777 133.350
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180326 330.1   11607695 620.0 10205950 545.1
# Vcells 12066910  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:47:41.905923
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.389   0.805 133.802
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180337 330.1   11607695 620.0 10205950 545.1
# Vcells 12066933  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:47:42.276906
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.008   0.735 133.512
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180348 330.1   11607695 620.0 10205950 545.1
# Vcells 12066956  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:47:42.636945
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.561   0.696 133.649
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180353 330.1   11607695 620.0 10205950 545.1
# Vcells 12066839  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:47:42.992812
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.896   0.722 135.113
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180362 330.1   11607695 620.0 10205950 545.1
# Vcells 12066796  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:47:43.349003
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.699   0.647 133.913
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180371 330.1   11607695 620.0 10205950 545.1
# Vcells 12066754  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:47:43.703883
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.095   0.742 134.816
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6180381 330.1   11607695 620.0 10205950 545.1
# Vcells 12066712  92.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 12
# Timestamp: 2024-09-12 15:47:44.063056
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.419   0.662 135.093
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185111 330.4   11607695 620.0 10205950 545.1
# Vcells 12126139  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:47:44.428373
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.320   1.299 134.977
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185122 330.4   11607695 620.0 10205950 545.1
# Vcells 12126164  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:47:44.780212
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.256   0.769 135.460
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185133 330.4   11607695 620.0 10205950 545.1
# Vcells 12126188  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:47:45.132057
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 127.151   1.632 136.959
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185144 330.4   11607695 620.0 10205950 545.1
# Vcells 12126212  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:47:45.486269
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 127.164   1.898 137.575
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185149 330.4   11607695 620.0 10205950 545.1
# Vcells 12126096  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 15
# Timestamp: 2024-09-12 15:47:45.842059
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.862   0.762 135.669
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185158 330.4   11607695 620.0 10205950 545.1
# Vcells 12126054  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:47:46.202065
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.666   0.669 135.149
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185137 330.4   11607695 620.0 10205950 545.1
# Vcells 12125159  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:45:24] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!
#
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:49:52.886425
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 120.149   0.720 124.900
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6170296 329.6   11607695 620.0 10205950 545.1
# Vcells 11932663  91.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:48] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:49:57.499858
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 127.551   0.605 130.110
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6170975 329.6   11607695 620.0 10205950 545.1
# Vcells 11941160  91.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:49:58.836802
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.297   0.586 131.420
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6171660 329.7   11607695 620.0 10205950 545.1
# Vcells 11949668  91.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:50:00.115613
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.943   0.753 132.282
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6172345 329.7   11607695 620.0 10205950 545.1
# Vcells 11958180  91.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 7
# Timestamp: 2024-09-12 15:50:00.813347
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.351   0.742 132.809
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6173030 329.7   11607695 620.0 10205950 545.1
# Vcells 11966688  91.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:50:01.478224
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.772   0.703 133.834
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175063 329.8   11607695 620.0 10205950 545.1
# Vcells 11992166  91.5   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:50:02.069236
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.140   0.703 132.953
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175074 329.8   11607695 620.0 10205950 545.1
# Vcells 11992189  91.5   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:50:02.581161
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 130.891   0.644 133.531
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175085 329.8   11607695 620.0 10205950 545.1
# Vcells 11992220  91.5   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:50:03.036507
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.586   1.121 134.237
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183185 330.3   11607695 620.0 10205950 545.1
# Vcells 12094071  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:50:03.45586
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 132.157   0.689 134.939
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183196 330.3   11607695 620.0 10205950 545.1
# Vcells 12094094  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:50:03.838327
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.470   0.883 135.491
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183207 330.3   11607695 620.0 10205950 545.1
# Vcells 12094117  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 17
# Timestamp: 2024-09-12 15:50:04.209532
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.761   0.724 134.409
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183218 330.3   11607695 620.0 10205950 545.1
# Vcells 12094140  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 15
# Timestamp: 2024-09-12 15:50:04.581324
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.972   0.721 135.219
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183229 330.3   11607695 620.0 10205950 545.1
# Vcells 12094163  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:50:04.937069
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.478   0.901 135.020
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183240 330.3   11607695 620.0 10205950 545.1
# Vcells 12094187  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 12
# Timestamp: 2024-09-12 15:50:05.29006
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 132.528   0.863 135.335
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183251 330.3   11607695 620.0 10205950 545.1
# Vcells 12094211  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:50:05.645123
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.120   0.659 135.212
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183262 330.3   11607695 620.0 10205950 545.1
# Vcells 12094235  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:50:05.995756
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.353   0.673 135.144
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183273 330.3   11607695 620.0 10205950 545.1
# Vcells 12094260  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:50:06.347007
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.670   0.897 134.281
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183284 330.3   11607695 620.0 10205950 545.1
# Vcells 12094285  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:50:06.698007
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.879   0.745 134.286
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183295 330.3   11607695 620.0 10205950 545.1
# Vcells 12094309  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:48] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:50:07.04934
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 128.493   1.319 135.612
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183300 330.3   11607695 620.0 10205950 545.1
# Vcells 12094129  92.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:50:07.400465
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 131.474   0.720 135.733
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185995 330.4   11607695 620.0 10205950 545.1
# Vcells 12127697  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:50:07.757043
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.146   1.509 137.165
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185996 330.4   11607695 620.0 10205950 545.1
# Vcells 12127391  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:50:08.107581
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 127.293   1.197 136.397
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6186001 330.4   11607695 620.0 10205950 545.1
# Vcells 12127218  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:50:08.460737
# Success: TRUE
#
# Task duration:
#    user  system elapsed
# 129.940   0.822 135.990
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185996 330.4   11607695 620.0 10205950 545.1
# Vcells 12126850  92.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:47:47] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/THP1mono20240412_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1mono20240412_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1Monocyte20240412_barcodes.csv", header=TRUE,row.names=1)
df_DNA <- df_DNA[, !grepl("ZC37|ZC60", colnames(df_DNA))]
df_RNA <- df_RNA[, !grepl("ZC37|ZC60", colnames(df_RNA))]
annot_DNA <- annot_DNA[!grepl("ZC37|ZC60", rownames(annot_DNA)), ]

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_THP1Monocyte.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:50:16.527389
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   7.135   0.337   7.490
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6168616 329.5   11607695 620.0 10205950 545.1
# Vcells 11081490  84.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:50:17.397585
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   7.171   0.417   7.696
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6181298 330.2   11607695 620.0 10205950 545.1
# Vcells 11151978  85.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:50:17.814928
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#
23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:50:23.87127
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   7.318   0.404   7.779
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6181465 330.2   11607695 620.0 10205950 545.1
# Vcells 11151361  85.1   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:50:24.224528
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   6.278   0.597   8.620
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184171 330.3   11607695 620.0 10205950 545.1
# Vcells 11166251  85.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:50:24.583713
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   7.023   0.434   7.878
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184182 330.3   11607695 620.0 10205950 545.1
# Vcells 11166275  85.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 7
# Timestamp: 2024-09-12 15:50:24.933943
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   7.383   0.418   8.111
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184192 330.3   11607695 620.0 10205950 545.1
# Vcells 11166299  85.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:50:25.289241
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#   7.241   0.431   8.099
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184187 330.3   11607695 620.0 10205950 545.1
# Vcells 11165931  85.2   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:09] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
####20240912
df_DNA <- read.csv("read_counts_R1R2/THP1_LPSIFNG_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_LPSIFNG_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNG_barcodes.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)


#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_THP1_LPSIFNG.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:50:49.987447
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  22.532   0.399  23.439
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6168900 329.5   11607695 620.0 10205950 545.1
# Vcells 11269886  86.0   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:50:51.18596
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#
23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:25] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:50:57.884698
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.623   0.449  26.152
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184513 330.3   11607695 620.0 10205950 545.1
# Vcells 11435983  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 15
# Timestamp: 2024-09-12 15:50:58.244227
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  25.194   0.422  26.425
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184522 330.3   11607695 620.0 10205950 545.1
# Vcells 11435941  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:50:58.597544
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.994   0.405  25.918
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184531 330.3   11607695 620.0 10205950 545.1
# Vcells 11435900  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:50:58.951979
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.493   0.723  26.725
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184536 330.3   11607695 620.0 10205950 545.1
# Vcells 11435727  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:50:59.305035
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.664   0.439  25.860
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184545 330.3   11607695 620.0 10205950 545.1
# Vcells 11435686  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:50:59.660113
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.490   0.520  26.039
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184534 330.3   11607695 620.0 10205950 545.1
# Vcells 11435121  87.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:50:26] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/THP1_IFNG_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_IFNG_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_IFNG_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_THP1_IFNG.csv")

df_DNA <- read.csv("read_counts_R1R2/THP1_IFNB_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_IFNB_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_IFNB_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_THP1_IFNB.csv")

df_DNA <- read.csv("read_counts_R1R2/THP1_Naive_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_Naive_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_Naive_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_THP1_Naive.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:51:27.739352
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#
23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:53:00.919739
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  39.901   0.328  40.788
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187022 330.5   11607695 620.0 10205950 545.1
# Vcells 11601565  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:53:01.295718
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  39.453   0.352  40.653
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187033 330.5   11607695 620.0 10205950 545.1
# Vcells 11601590  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:53:01.65448
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  37.195   0.933  41.822
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187044 330.5   11607695 620.0 10205950 545.1
# Vcells 11601614  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:53:02.014455
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  39.312   0.446  42.064
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187055 330.5   11607695 620.0 10205950 545.1
# Vcells 11601638  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:53:02.37687
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  39.526   0.338  41.261
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187065 330.5   11607695 620.0 10205950 545.1
# Vcells 11601598  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:53:02.738247
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  39.548   0.412  41.235
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187072 330.5   11607695 620.0 10205950 545.1
# Vcells 11601490  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:53:03.101523
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  38.925   0.647  41.692
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187071 330.5   11607695 620.0 10205950 545.1
# Vcells 11601118  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:53:03.464891
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  39.684   0.363  41.039
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187050 330.5   11607695 620.0 10205950 545.1
# Vcells 11600222  88.6   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:52:15] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/HMC3_LPSIFNG_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_LPSIFNG_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNG_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_HMC3_LPSIFNG.csv")

df_DNA <- read.csv("read_counts_R1R2/HMC3_IFNB_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_IFNB_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_IFNB_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_HMC3_IFNB.csv")

df_DNA <- read.csv("read_counts_R1R2/HMC3_Naive_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_Naive_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_Naive_barcodes.csv", header=TRUE,row.names=1)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.154   0.914  26.187
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187112 330.5   11607695 620.0 10205950 545.1
# Vcells 11446213  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:54:38.951301
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.022   0.439  25.275
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187123 330.5   11607695 620.0 10205950 545.1
# Vcells 11446236  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:54:39.302597
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.540   0.431  25.555
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187134 330.5   11607695 620.0 10205950 545.1
# Vcells 11446260  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:54:39.6551
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.390   0.465  25.477
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187145 330.5   11607695 620.0 10205950 545.1
# Vcells 11446284  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:09] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:54:40.008669
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.507   0.358  25.351
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187156 330.5   11607695 620.0 10205950 545.1
# Vcells 11446302  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:54:40.362385
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.522   0.398  25.586
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187165 330.5   11607695 620.0 10205950 545.1
# Vcells 11446260  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:54:40.71461
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.255   0.389  25.557
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187174 330.5   11607695 620.0 10205950 545.1
# Vcells 11446218  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:54:41.066967
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.114   0.384  25.195
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187181 330.5   11607695 620.0 10205950 545.1
# Vcells 11446110  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:54:41.421916
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.801   0.406  25.616
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187190 330.5   11607695 620.0 10205950 545.1
# Vcells 11446068  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:54:41.7783
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.443   0.371  25.190
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187197 330.5   11607695 620.0 10205950 545.1
# Vcells 11445960  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:54:42.136632
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.303   0.392  25.336
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6187172 330.5   11607695 620.0 10205950 545.1
# Vcells 11444932  87.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:08] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/HMC3_IFNG_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_IFNG_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_IFNG_barcodes.csv", header=TRUE,row.names=1)
df_DNA <- df_DNA[, !grepl("ZC23", colnames(df_DNA))]
df_RNA <- df_RNA[, !grepl("ZC23", colnames(df_RNA))]
annot_DNA <- annot_DNA[!grepl("ZC23", rownames(annot_DNA)), ]
df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)


#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]
###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)
write.csv(test_results,"20240912_MAD_HMC3_IFNG.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 10
# Timestamp: 2024-09-12 15:55:04.185677
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.443   0.411  21.160
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6169523 329.5   11607695 620.0 10205950 545.1
# Vcells 11220919  85.7   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 12
# Timestamp: 2024-09-12 15:55:05.082154
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.169   0.407  21.766
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178830 330.0   11607695 620.0 10205950 545.1
# Vcells 11320477  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:55:05.592866
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.130   0.408  21.564
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178841 330.0   11607695 620.0 10205950 545.1
# Vcells 11320501  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:55:05.986986
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.702   0.412  21.241
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178852 330.0   11607695 620.0 10205950 545.1
# Vcells 11320528  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 7
# Timestamp: 2024-09-12 15:55:06.354257
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.227   0.453  21.840
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178863 330.0   11607695 620.0 10205950 545.1
# Vcells 11320551  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 3
# Timestamp: 2024-09-12 15:55:06.71164
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.940   0.440  21.664
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178874 330.0   11607695 620.0 10205950 545.1
# Vcells 11320574  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 1
# Timestamp: 2024-09-12 15:55:07.064183
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  19.002   0.485  21.415
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178885 330.0   11607695 620.0 10205950 545.1
# Vcells 11320597  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 24
# Timestamp: 2024-09-12 15:55:07.418949
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.358   0.376  21.742
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178896 330.0   11607695 620.0 10205950 545.1
# Vcells 11320622  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:55:07.773445
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.165   0.396  21.734
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178905 330.0   11607695 620.0 10205950 545.1
# Vcells 11320579  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:55:08.126679
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.614   0.419  21.752
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178915 330.0   11607695 620.0 10205950 545.1
# Vcells 11320536  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:55:08.480514
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.160   0.392  21.611
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178926 330.0   11607695 620.0 10205950 545.1
# Vcells 11320559  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 17
# Timestamp: 2024-09-12 15:55:08.833079
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.947   0.370  21.783
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178937 330.0   11607695 620.0 10205950 545.1
# Vcells 11320582  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:55:09.186222
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.915   0.444  21.693
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178948 330.0   11607695 620.0 10205950 545.1
# Vcells 11320605  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 15
# Timestamp: 2024-09-12 15:55:09.539192
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.012   0.400  21.762
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178959 330.0   11607695 620.0 10205950 545.1
# Vcells 11320628  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 13
# Timestamp: 2024-09-12 15:55:09.89119
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.036   0.443  21.580
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6178970 330.0   11607695 620.0 10205950 545.1
# Vcells 11320652  86.4   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 11
# Timestamp: 2024-09-12 15:55:10.244694
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.953   0.458  22.597
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185048 330.4   11607695 620.0 10205950 545.1
# Vcells 11385169  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:55:10.608242
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.741   0.497  22.830
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185059 330.4   11607695 620.0 10205950 545.1
# Vcells 11385194  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:55:10.963737
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  19.834   0.803  23.259
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185070 330.4   11607695 620.0 10205950 545.1
# Vcells 11385218  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 4
# Timestamp: 2024-09-12 15:55:11.320417
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.906   0.429  22.289
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185081 330.4   11607695 620.0 10205950 545.1
# Vcells 11385242  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 2
# Timestamp: 2024-09-12 15:55:11.675991
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  20.397   0.449  22.448
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185092 330.4   11607695 620.0 10205950 545.1
# Vcells 11385266  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:43] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 22
# Timestamp: 2024-09-12 15:55:12.032452
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.053   0.507  22.762
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185099 330.4   11607695 620.0 10205950 545.1
# Vcells 11385216  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 20
# Timestamp: 2024-09-12 15:55:12.403111
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.327   0.370  22.483
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185108 330.4   11607695 620.0 10205950 545.1
# Vcells 11385174  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:55:12.770953
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.315   0.433  22.521
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185109 330.4   11607695 620.0 10205950 545.1
# Vcells 11384868  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 14
# Timestamp: 2024-09-12 15:55:13.14034
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  21.380   0.407  22.219
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6185088 330.4   11607695 620.0 10205950 545.1
# Vcells 11383972  86.9   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:54:42] loading futile.logger package
#
# stderr and stdout:
#
#
# Analysis done!

# %%
df_DNA <- read.csv("read_counts_R1R2/HEK293T_DNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HEK293T_RNA_matched_barcodes_reshaped_altref.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HEK293T_barcodes.csv", header=TRUE,row.names=1)
df_DNA <- df_DNA[, !grepl("ZC65|ZC66", colnames(df_DNA))]
df_RNA <- df_RNA[, !grepl("ZC65|ZC66", colnames(df_RNA))]
annot_DNA <- annot_DNA[!grepl("ZC65|ZC66", rownames(annot_DNA)), ]

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}
#Read negative controls
negative <- read.csv('indexing/mpra3_negatives.csv' , sep="\t",header=FALSE)
control <- as.character(negative$V1)#V1 is the sequence_ID

annot_DNA <- annot_DNA [!grepl("REF", rownames(annot_DNA )), ]
##############################################################
total_columns <- ncol(df_DNA)
selected_columns <- seq(from = 1, to = total_columns)[((seq(from = 1, to = total_columns) - 1) %% 32) < 15]
df_DNA <- df_DNA[, selected_columns]
df_RNA <- df_RNA[, selected_columns]
annot_DNA <- annot_DNA[selected_columns,]

###############################################################
obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )

#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   

obj <- analyzeQuantification(
                            obj = obj, 
                            dnaDesign = ~ Barcode_Allele+Test, 
                            rnaDesign = ~ 1
                            )
test_results <- testEmpirical(obj = obj,twoSided = TRUE)

write.csv(test_results,"20240912_MAD_HEK293T.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 21
# Timestamp: 2024-09-12 15:55:37.498616
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.122   0.389  23.725
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6169558 329.5   11607695 620.0 10205950 545.1
# Vcells 11171144  85.3   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:13] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 19
# Timestamp: 2024-09-12 15:55:38.763102
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.703   0.392  24.527
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175555 329.9   11607695 620.0 10205950 545.1
# Vcells 11234930  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:13] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 18
# Timestamp: 2024-09-12 15:55:39.368918
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.929   0.356  24.874
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175566 329.9   11607695 620.0 10205950 545.1
# Vcells 11234953  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:13] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 16
# Timestamp: 2024-09-12 15:55:39.761983
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.629   0.398  24.708
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175577 329.9   11607695 620.0 10205950 545.1
# Vcells 11234980  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:13] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 12
# Timestamp: 2024-09-12 15:55:40.117732
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.067   0.386  24.567
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175588 329.9   11607695 620.0 10205950 545.1
# Vcells 11235003  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 9
# Timestamp: 2024-09-12 15:55:40.467983
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.451   0.411  24.400
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175599 329.9   11607695 620.0 10205950 545.1
# Vcells 11235027  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 8
# Timestamp: 2024-09-12 15:55:40.816094
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.220   0.399  23.947
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175610 329.9   11607695 620.0 10205950 545.1
# Vcells 11235050  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 6
# Timestamp: 2024-09-12 15:55:41.165851
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.416   0.428  24.368
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175621 329.9   11607695 620.0 10205950 545.1
# Vcells 11235081  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 5
# Timestamp: 2024-09-12 15:55:41.517149
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  23.494   0.423  24.570
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6175632 329.9   11607695 620.0 10205950 545.1
# Vcells 11235104  85.8   23112658 176.4 23112658 176.4
#
# Log messages:
# INFO [2024-09-12 15:55:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 23
# Timestamp: 2024-09-12 15:55:41.868071
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  24.001   0.354  24.900
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  