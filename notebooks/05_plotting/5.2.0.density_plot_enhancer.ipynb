# %%
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import os

# %%
def plot_density(cell):
    # Set the style
    sns.set(style="white")
    # Create the plot
    plt.figure(figsize=(10, 6))
    sns.kdeplot(df_immune[cell], label='Immune Enhancers', color='blue', linestyle='-', linewidth=1.5,fill=True)
    sns.kdeplot(df_other[cell], label='Low ATAC Enhancers', color='black', linestyle='-', linewidth=1.5,fill=True)
    sns.kdeplot(df_ubiquitous[cell], label='Ubiquitous Enhancers', color='red', linestyle='-', linewidth=1.5,fill=True)
    # Adding labels and title
    plt.xlabel(f'{cell} Enhancer MAD Scores of Transcription')
    plt.ylabel('Density')
    plt.title(f'{cell}')
    # Adding legend
    plt.legend(title='Enhancer Type')
    # Show the plot
    plt.savefig(f'densityplot_enhancer_type_{cell}.pdf', dpi=300, bbox_inches='tight')
    plt.show()

    # Assume df_immune['THP1_LPSIFNG'] and df_other['THP1_LPSIFNG'] are your two independent samples.
    result1 = stats.mannwhitneyu(df_immune[cell], df_other[cell], alternative='two-sided')
    result2 = stats.mannwhitneyu(df_ubiquitous[cell], df_other[cell], alternative='two-sided')
    print("immune vs other; p-value:", result1.pvalue)
    print("ubiquitous vs other; p-value:", result2.pvalue)

# %%
############################################################
# Step 1: Reading MAD Scores and Merging with Index/Annotations
############################################################

# List of keyword patterns to search for in filenames
keywords = [
    'THP1Macrophage', 'Brain', 'HEK293T', 'Cortex', 'Striatum', 'Hippocampus','HMC3Cell',
    'HMC3_IFNB', 'HMC3_IFNG', 'HMC3_Naive', 'HMC3_LPSIFNG', 'THP1Monocyte',
    'THP1_Naive', 'THP1_IFNG', 'THP1_IFNB', 'THP1_LPSIFNG'
]

# Directory containing your MAD score CSV files
path = 'enhancer_activities/MAD_OneTail_NoControl/'

# Initialize an empty DataFrame to store combined results
df = pd.DataFrame()

# Loop through each keyword and each file in the directory
for key in keywords:
    for f in os.listdir(path):
        if (
            key in f
            and "old" not in f
            and "hold" not in f
            and not f.startswith("._")
        ):
            df_new = pd.read_csv(
                os.path.join(path, f),
                index_col=0
            )["pval.mad"]

            df_new = pd.DataFrame(df_new)
            df_new.columns = [key]
            df = pd.concat([df, df_new], axis=1)

# Load indexing files (metadata)
df_index = pd.read_csv(
    'indexing/ALT_REF_LookUpTable_filtered_amended_alleleOnly_20240605.csv',
    index_col=0
)
df_annotation = pd.read_csv(
    'indexing/SNP_haploregannotatr_ATAC_tss_SNPFunction_spliceai_bayesianML_Bellenguez_TSS_genomicML_logFC_diff_MAFCorrect_REFindex_catlas_with_all_peakfiles_variant_category_20260310.csv',
    index_col=0
)

# Merge df_index and df_annotation
df_index_annotation = pd.merge(df_index, df_annotation, left_index=True, right_index=True)

# Filter df to keep rows whose index starts with 'alt' or 'ref'
mask = df.index.astype(str).str.startswith('alt') | df.index.astype(str).str.startswith('ref')
filtered_df = df[mask]

# Merge filtered_df with annotation to get separate alt/ref data
df_alt = pd.merge(filtered_df, df_index_annotation, left_index=True, right_index=True)
df_ref = pd.merge(filtered_df, df_index_annotation.set_index("1"), left_index=True, right_index=True)

# Combine alt and ref, reorder to match original
df_mpra_annotation = pd.concat([df_alt, df_ref]).loc[filtered_df.index]

# Create a column for absolute distance to TSS
df_mpra_annotation['absoluate_distance_to_tss'] = df_mpra_annotation['distance_to_tss'].abs()

# Remove duplicated rows based on index, keeping the first occurrence
df_mpra_annotation_unique = df_mpra_annotation[~df_mpra_annotation.index.duplicated(keep='first')]
df_mpra_annotation_unique
# Out:
# /var/folders/sh/7r2k6xws40df6nh1bf5t_1x40000gn/T/ipykernel_53963/3681954048.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_mpra_annotation['absoluate_distance_to_tss'] = df_mpra_annotation['distance_to_tss'].abs()
#                                                     THP1Macrophage     Brain  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...        0.001765  0.188590
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...        0.837334  0.639903
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...        0.054455  0.150777
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...        0.973911  0.821705
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...        0.954601  0.969509
# ...                                                            ...       ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...        0.333542  0.933314
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...        0.295088  0.856594
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...        0.960112  0.830979
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...        0.624618  0.071043
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...        0.279954  0.286859
#
#                                                      HEK293T    Cortex  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  0.010447  0.322655
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  0.983199  0.799595
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  0.028097  0.814269
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  0.930123  0.583045
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  0.926855  0.964454
# ...                                                      ...       ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  0.813532  0.916938
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  0.582507  0.916202
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  0.686254  0.925415
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  0.075736  0.049827
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  0.425383  0.559209
#
#                                                     Striatum  Hippocampus  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  0.519032     0.316151
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  0.673714     0.776677
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  0.681148     0.512242
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  0.522951     0.684094
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  0.933899     0.971509
# ...                                                      ...          ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  0.946217     0.914545
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  0.769515     0.793902
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  0.892002     0.639602
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  0.078954     0.133840
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  0.508043     0.562885
#
#                                                     HMC3Cell  HMC3_IFNB  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  0.150031   0.156222
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  0.958347   0.951750
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  0.243805   0.394417
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  0.907126   0.917069
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  0.867091   0.869490
# ...                                                      ...        ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  0.568131   0.675672
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  0.258771   0.323283
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  0.597486   0.635336
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  0.125426   0.201565
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  0.163182   0.220223
#
#                                                     HMC3_IFNG  HMC3_Naive  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...   0.086246    0.042867
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...   0.972169    0.970266
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...   0.161525    0.066196
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...   0.856296    0.928403
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...   0.842528    0.887963
# ...                                                       ...         ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...   0.506487    0.450971
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...   0.166683    0.145644
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...   0.611141    0.527484
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...   0.086813    0.052988
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...   0.085241    0.076773
#
#                                                     ...  VIP  VIP_1  VIP_2  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  ...    1      1      1
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  ...    0      0      0
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  ...    1      1      1
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  ...    0      0      0
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  ...    0      0      0
# ...                                                 ...  ...    ...    ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  ...    0      0      0
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  ...    0      0      0
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  ...    0      0      0
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  ...    0      0      0
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  ...    0      0      0
#
#                                                     VIP_3  VIP_4  VIP_5 VIP_6  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...      1      1      1     1
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...      0      0      0     0
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...      1      1      1     1
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...      0      0      0     0
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...      0      0      0     0
# ...                                                   ...    ...    ...   ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...      0      0      0     0
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...      0      0      0     0
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...      0      0      0     0
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...      0      0      0     0
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...      0      0      0     0
#
#                                                    VIP_7   Variant_Category  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...     1              Broad
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...     0           Low-ATAC
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...     1              Broad
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...     0    Immune-enriched
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...     0              Broad
# ...                                                  ...                ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...     0    Immune-enriched
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...     0    Immune-enriched
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...     0    Immune-enriched
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...     0    Immune-enriched
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...     0  Neuronal-enriched
#
#                                                    absoluate_distance_to_tss
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...                      1547
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...                     28082
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...                       950
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...                       799
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...                       523
# ...                                                                      ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...                     18657
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...                      1116
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...                     19137
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...                      4787
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...                      1010
#
# [1415 rows x 352 columns]

# %%
columns_to_combine = ['THP1Macrophage']

df_immune = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Immune-enriched']
df_lowatac = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Low-ATAC']
df_broad = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Broad']
df_neuron = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Neuronal-enriched']
df_glial = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Glial-enriched']

combined_values_immune = df_immune[columns_to_combine].values.flatten().tolist()
combined_values_lowatac = df_lowatac[columns_to_combine].values.flatten().tolist()
combined_values_broad = df_broad[columns_to_combine].values.flatten().tolist()
combined_values_neuron = df_neuron[columns_to_combine].values.flatten().tolist()
combined_values_glial = df_glial[columns_to_combine].values.flatten().tolist()

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="ticks", context="paper")

plt.figure(figsize=(5, 5))

sns.kdeplot(
    combined_values_lowatac,
    label='Low ATAC Sequences',
    color='#CFCFCF',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_immune,
    label='Immune CREs',
    color='#ff2a60',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_broad,
    label='Broad CREs',
    color='#fde725',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_neuron,
    label='Neuronal CREs',
    color='#180aff',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_glial,
    label='Glial CREs',
    color='#f46e00',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

plt.xlabel('P-value of Transcription Activities', fontsize=16, labelpad=10)
plt.ylabel('Density', fontsize=16, labelpad=10)
plt.title('Brain', fontsize=17, pad=15)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.tick_params(axis='both', which='both', direction='in', length=6, width=1, top=True, right=True)

plt.xlim(0, 1)
plt.ylim(0, 1.5)

plt.legend(
    title='Sequence Classification',
    title_fontsize=14,
    fontsize=12,
    loc='upper right',
    frameon=True,
    shadow=False,
    borderpad=1
)

plt.tight_layout()

# plt.savefig('densityplot_enhancer_thp1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
columns_to_combine = ['Brain']

df_immune = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Immune-enriched']
df_lowatac = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Low-ATAC']
df_broad = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Broad']
df_neuron = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Neuronal-enriched']
df_glial = df_mpra_annotation_unique[df_mpra_annotation_unique['Variant_Category'] == 'Glial-enriched']

combined_values_immune = df_immune[columns_to_combine].values.flatten().tolist()
combined_values_lowatac = df_lowatac[columns_to_combine].values.flatten().tolist()
combined_values_broad = df_broad[columns_to_combine].values.flatten().tolist()
combined_values_neuron = df_neuron[columns_to_combine].values.flatten().tolist()
combined_values_glial = df_glial[columns_to_combine].values.flatten().tolist()

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="ticks", context="paper")

plt.figure(figsize=(5, 5))

sns.kdeplot(
    combined_values_lowatac,
    label='Low ATAC Sequences',
    color='#CFCFCF',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_immune,
    label='Immune CREs',
    color='#ff2a60',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_broad,
    label='Broad CREs',
    color='#fde725',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_neuron,
    label='Neuronal CREs',
    color='#180aff',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

sns.kdeplot(
    combined_values_glial,
    label='Glial CREs',
    color='#f46e00',
    linestyle='-',
    linewidth=2,
    fill=True,
    alpha=0.2
)

plt.xlabel('P-value of Transcription Activities', fontsize=16, labelpad=10)
plt.ylabel('Density', fontsize=16, labelpad=10)
plt.title('Brain', fontsize=17, pad=15)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.tick_params(axis='both', which='both', direction='in', length=6, width=1, top=True, right=True)

plt.xlim(0, 1)
plt.ylim(0, 1.5)

plt.legend(
    title='Sequence Classification',
    title_fontsize=14,
    fontsize=12,
    loc='upper right',
    frameon=True,
    shadow=False,
    borderpad=1
)

plt.tight_layout()

# plt.savefig('densityplot_enhancer_thp1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
for i in df_mpra_annotation_unique.columns:
    print(i)
# Out:
# THP1Macrophage
# Brain
# HEK293T
# Cortex
# Striatum
# Hippocampus
# HMC3Cell
# HMC3_IFNB
# HMC3_IFNG
# HMC3_Naive
# HMC3_LPSIFNG
# THP1Monocyte
# THP1_Naive
# THP1_IFNG
# THP1_IFNB
# THP1_LPSIFNG
# 1
# RSID
# Contributor
# nearest_gene
# rsID
# chr_number
# pos_hg38
# ref
# alt
# AFR
# AMR
# ASN
# EUR
# MAF_Average
# Rare_Common
# Rare_Low_Common
# GERP_cons
# SiPhy_cons
# Chromatin_States
# Chromatin_States_Imputed
# Chromatin_Marks
# DNAse
# Proteins
# eQTL
# gwas
# grasp
# Motifs
# GENCODE_id
# GENCODE_name
# GENCODE_direction
# GENCODE_distance
# RefSeq_id
# RefSeq_name
# RefSeq_direction
# RefSeq_distance
# dbSNP_functional_annotation
# query_snp_rsid
# Promoter_histone_marks
# Enhancer_histone_marks
# snp_original
# snp_original_haploreghg38
# SNP_ID
# REFALT_Flip
# allele
# rsid
# center
# chr
# snp
# a1
# a1_spliceai
# a2
# a2_spliceai
# start
# end
# summit
# Mef2
# PU.1
# Irf
# STAT
# NF-kappaB
# AP-1
# Major
# Minor
# Rare_Common.1
# rsid_nearestgene
# coordinate
# cpg_inter
# cpg_islands
# cpg_shelves
# cpg_shores
# genes_1to5kb
# genes_3UTRs
# genes_5UTRs
# genes_exons
# genes_intergenic
# genes_intronexonboundaries
# genes_introns
# genes_promoters
# Encode_Monocyte_DHS_hg38.narrowPeak
# Gosselin_Microglia_ATAC_hg38.idr.optimal_peak.narrowPeak
# HMC3.idr.optimal_peak.narrowPeak
# Kosoy_Microglia_OCRs_hg38.bed
# M2_IFNG.idr.optimal_peak.narrowPeak
# M2_NAIVE.idr.optimal_peak.narrowPeak
# mono_hg38.bed
# THP1_IFNB_4hrs.idr.optimal_peak.narrowPeak
# THP1_IFNG_4hrs.idr.optimal_peak.narrowPeak
# THP1_LPSIFNG_4hrs.idr.optimal_peak.narrowPeak
# THP1_monocytes.idr.optimal_peak.narrowPeak
# THP1_Naive_4hrs.idr.optimal_peak.narrowPeak
# TLR4_IFNG.idr.optimal_peak.narrowPeak
# TLR4_IFNG_LPS.idr.optimal_peak.narrowPeak
# nk_hg38.bed
# Mic.DUSP1.peak.annotation.txt
# Ast.TPST1.peak.annotation.txt
# Exc.L6.CT.peak.annotation.txt
# Exc.L6b.peak.annotation.txt
# Ast.GRM3.peak.annotation.txt
# Exc.L5.6.RORB.LINC02196.peak.annotation.txt
# cd4_hg38.bed
# Exc.L6.THEMIS.NFIA.peak.annotation.txt
# Inh.L1.6.LAMP5.CA13.peak.annotation.txt
# Inh.L5.6.PVALB.STON2.peak.annotation.txt
# Exc.L2.3.CBLN2.LINC02306.peak.annotation.txt
# cd8_hg38.bed
# Inh.ENOX2.SPHKAP.peak.annotation.txt
# Inh.LAMP5.NRG1..Rosehip..peak.annotation.txt
# Exc.L3.5.RORB.PLCH1.peak.annotation.txt
# Ast.DPP10.peak.annotation.txt
# Inh.CUX2.MSR1.peak.annotation.txt
# Inh.GPC5.RIT2.peak.annotation.txt
# Inh.FBN2.EPB41L4A.peak.annotation.txt
# Inh.L3.5.SST.MAFB.peak.annotation.txt
# Inh.VIP.TSHZ2.peak.annotation.txt
# Exc.L4.5.RORB.GABRG1.peak.annotation.txt
# Inh.L5.6.SST.TH.peak.annotation.txt
# Exc.L4.5.RORB.IL1RAPL2.peak.annotation.txt
# Inh.PVALB.SULF1.peak.annotation.txt
# Inh.PVALB.CA8..Chandelier..peak.annotation.txt
# Inh.PVALB.HTR4.peak.annotation.txt
# Exc.L3.4.RORB.CUX2.peak.annotation.txt
# HEK293_ATAC_high_depth.idr.conservative_peak.narrowPeak
# Inh.RYR3.TSHZ2.peak.annotation.txt
# Exc.L5.6.IT.Car3.peak.annotation.txt
# Inh.VIP.THSD7B.peak.annotation.txt
# Inh.ALCAM.TRPM3.peak.annotation.txt
# Opc.GRIA4.peak.annotation.txt
# Oli.OPALIN.peak.annotation.txt
# Opc.TPST1.peak.annotation.txt
# Oli.RASGRF1.peak.annotation.txt
# Exc.RELN.CHD7.peak.annotation.txt
# OPC.DOCK5.peak.annotation.txt
# Mic.P2RY12.peak.annotation.txt
# H1resting.idr.optimal_peak.narrowPeak
# H1stimulated.idr.optimal_peak.narrowPeak
# WTC11resting.idr.optimal_peak.narrowPeak
# WTC11stimulated.idr.optimal_peak.narrowPeak
# Alasoo_Macrophage_ATAC_hg38.bed
# Corces_Microglia_sgATAC_hg38.idr.optimal.narrowPeak
# HEK293T_ATAC.idr.conservative_peak.narrowPeak
# B_cells_hg38.bed
# dendritic_hg38.bed
# basophil_hg38.bed
# progen_hg38.bed
# GC_content
# distance_to_tss
# SNP_Function
# spliceai
# spliceai_significant
# ML_majormino_logFC_HEK293T_ATAC_202408
# ML_majormino_logFC_HEK293_ATAC_high_de
# ML_majormino_logFC_Mouse_Cortex_AgeB-m
# ML_majormino_logFC_Mouse_Cortex_AgeC-m
# ML_majormino_logFC_Mouse_Striatum_AgeB
# ML_majormino_logFC_Mouse_Striatum_AgeC
# ML_majormino_logFC_THP1_IFNB-Calvin_20
# ML_majormino_logFC_THP1_IFNG-Calvin_20
# ML_majormino_logFC_THP1_LPSIFNG-Calvin
# ML_majormino_logFC_THP1_Naive-Calvin_2
# ML_majormino_logFC_THP1_monocyte0729_2
# variant_id
# Bellenguez_p_value
# Bellenguez_p_value_negLog10
# location
# gene_name
# closest_protein_coding_gene_TSS
# distance_to_closest_protein_coding_TSS
# hierarchical_label
# rsid_gene_label
# rsid_gene_tss
# ML_majorminor_logFC_genomic_H1_IFNB-model
# ML_majorminor_logFC_genomic_H1_resting-model
# ML_majorminor_logFC_genomic_HEK293T_ATAC
# ML_majorminor_logFC_genomic_HEK293_ATAC_high_depth0729
# ML_majorminor_logFC_genomic_Mouse_Cortex_AgeB-model
# ML_majorminor_logFC_genomic_Mouse_Cortex_AgeC-model
# ML_majorminor_logFC_genomic_Mouse_Striatum_AgeB
# ML_majorminor_logFC_genomic_Mouse_Striatum_AgeC
# ML_majorminor_logFC_genomic_THP1_IFNB-Calvin
# ML_majorminor_logFC_genomic_THP1_IFNG-Calvin
# ML_majorminor_logFC_genomic_THP1_LPSIFNG-Calvin
# ML_majorminor_logFC_genomic_THP1_Naive-Calvin
# ML_majorminor_logFC_genomic_THP1_monocyte0729
# ML_majorminor_logFC_genomic_WTC11_IFNB
# ML_majorminor_logFC_genomic_WTC11_resting
# ML_majorminor_diff_genomic_H1_IFNB-model
# ML_majorminor_diff_genomic_H1_resting-model
# ML_majorminor_diff_genomic_HEK293T_ATAC
# ML_majorminor_diff_genomic_HEK293_ATAC_high_depth0729
# ML_majorminor_diff_genomic_Mouse_Cortex_AgeB-model
# ML_majorminor_diff_genomic_Mouse_Cortex_AgeC-model
# ML_majorminor_diff_genomic_Mouse_Striatum_AgeB
# ML_majorminor_diff_genomic_Mouse_Striatum_AgeC
# ML_majorminor_diff_genomic_THP1_IFNB-Calvin
# ML_majorminor_diff_genomic_THP1_IFNG-Calvin
# ML_majorminor_diff_genomic_THP1_LPSIFNG-Calvin
# ML_majorminor_diff_genomic_THP1_Naive-Calvin
# ML_majorminor_diff_genomic_THP1_monocyte0729
# ML_majorminor_diff_genomic_WTC11_IFNB
# ML_majorminor_diff_genomic_WTC11_resting
# ref_index
# ACBGM
# AMY
# ASCNT
# ASCNT_1
# ASCNT_2
# ASCNT_3
# ASCT
# ASCT_1
# ASCT_2
# ASCT_3
# BFEXA
# BNGA
# CBGA
# CBGRC
# CBINH
# CHO
# CNGA
# CNGA_1
# CNGA_2
# CNMIX
# COP
# CT
# CTXGA
# CT_1
# CT_2
# D12NAC
# D1CaB
# D1Pu
# D2CaB
# D2Pu
# EC
# ERC_1
# ERC_2
# ET
# FOXP2
# FOXP2_1
# FOXP2_2
# FOXP2_3
# FOXP2_4
# ICGA_1
# ICGA_2
# ITL23
# ITL23_1
# ITL23_2
# ITL23_3
# ITL23_4
# ITL23_5
# ITL23_6
# ITL34
# ITL4
# ITL45
# ITL45_1
# ITL45_2
# ITL4_1
# ITL4_2
# ITL5
# ITL5_1
# ITL5_2
# ITL5_3
# ITL5_4
# ITL6_1
# ITL6_1_1
# ITL6_1_2
# ITL6_2
# ITL6_2_1
# ITL6_2_2
# ITV1C
# ITV1C_1
# ITV1C_2
# ITV1C_3
# L6B
# L6B_1
# L6B_2
# LAMP5_1
# LAMP5_2
# MBGA
# MDGA
# MGC
# MGC_1
# MGC_2
# MSN
# MSN_1
# MSN_2
# MSN_3
# NP
# NP_1
# NP_2
# NP_3
# OGC
# OGC_1
# OGC_2
# OGC_3
# OPC
# PER
# PIR
# PKJ_1
# PKJ_2
# PRERC
# PVALB
# PVALB_1
# PVALB_2
# PVALB_3
# PVALB_4
# PV_ChCs
# SEPGA
# SIGA
# SMC
# SNCG
# SNCG_1
# SNCG_2
# SNCG_3
# SNCG_4
# SNCG_5
# SST
# SST_1
# SST_2
# SST_3
# SST_4
# SST_5
# SST_CHODL
# SUB
# THMGA
# THMGA_1
# THMGA_2
# TP
# VIP
# VIP_1
# VIP_2
# VIP_3
# VIP_4
# VIP_5
# VIP_6
# VIP_7
# Variant_Category
# absoluate_distance_to_tss

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency


# =========================================================
# Make text editable in Illustrator
# =========================================================
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['text.usetex'] = False
mpl.rcParams['font.family'] = 'Arial'


# =========================================================
# 1. Settings
# =========================================================
sample_cols = [
    'THP1Macrophage',
    'Brain',
    'HEK293T'
]

# Significant CRE threshold: p < 0.1
p_thresh = 0.1


cat_map = {
    'Low-ATAC': 'Low ATAC Sequences',
    'Immune-enriched': 'Immune CREs',
    'Broad': 'Broad CREs',
    'Neuronal-enriched': 'Neuronal CREs',
    'Glial-enriched': 'Glial CREs',
}


color_map_sample = {
    'Brain': '#2D33FF',
    'THP1Macrophage': '#FF3B73',
    'HEK293T': '#43C000',
}


# Order used in the grouped bar plot
bar_plot_order = [
    'Immune CREs',
    'Neuronal CREs',
    'Broad CREs',
    'Glial CREs',
    'Low ATAC Sequences',
]


# Order used when printing chi-square contingency tables
chi2_plot_order = [
    'Low ATAC Sequences',
    'Immune CREs',
    'Broad CREs',
    'Neuronal CREs',
    'Glial CREs',
]


# =========================================================
# 2. Build long summary table
# =========================================================
all_summary = []

for sample_col in sample_cols:

    df_plot = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(cat_map.keys())
    ].copy()

    df_plot = df_plot[
        ['Variant_Category', sample_col]
    ].copy()

    # Convert p-values to numeric
    df_plot[sample_col] = pd.to_numeric(
        df_plot[sample_col],
        errors='coerce'
    )

    # Remove missing p-values
    df_plot = df_plot.dropna(
        subset=[sample_col]
    ).copy()

    # Rename CRE categories
    df_plot['CRE_type'] = df_plot['Variant_Category'].map(cat_map)

    # Significant CRE definition: p < 0.1
    df_plot['significant'] = df_plot[sample_col] < p_thresh

    summary = (
        df_plot
        .groupby('CRE_type')
        .agg(
            total_count=('significant', 'size'),
            significant_count=('significant', 'sum')
        )
        .reindex(bar_plot_order)
        .reset_index()
    )

    summary['sample'] = sample_col

    summary['significant_fraction'] = (
        summary['significant_count']
        / summary['total_count']
    )

    summary['significant_fraction_pct'] = (
        summary['significant_fraction'] * 100
    )

    all_summary.append(summary)


summary_long = pd.concat(
    all_summary,
    axis=0,
    ignore_index=True
)


print("\nSummary table using p < 0.1:")
print(summary_long)


# Save the summary table
summary_long.to_csv(
    'grouped_bar_significant_fraction_p01_summary.csv',
    index=False
)


# =========================================================
# 3. Plot grouped bar plot
# =========================================================
sns.set(
    style='ticks',
    context='paper'
)

fig, ax = plt.subplots(
    figsize=(10, 5)
)


sns.barplot(
    data=summary_long,
    x='CRE_type',
    y='significant_fraction_pct',
    hue='sample',
    order=bar_plot_order,
    hue_order=sample_cols,
    palette=color_map_sample,
    edgecolor='black',
    errorbar=None,
    ax=ax
)


# Set transparency
for patch in ax.patches:
    patch.set_alpha(0.7)


# Axis labels
ax.set_xlabel(
    '',
    fontsize=18
)

ax.set_ylabel(
    'Significant CREs within type (%)',
    fontsize=18,
    labelpad=10
)


# X-axis labels
ax.set_xticks(
    range(len(bar_plot_order))
)

ax.set_xticklabels(
    bar_plot_order,
    rotation=30,
    ha='right',
    fontsize=15
)


# Tick formatting
ax.tick_params(
    axis='both',
    which='both',
    direction='in',
    top=True,
    right=True,
    labelsize=15,
    length=6,
    width=1.2
)


# Legend
legend = ax.legend(
    title='',
    frameon=True,
    fontsize=14,
    title_fontsize=15
)


# Keep all four spines
sns.despine(
    top=False,
    right=False
)


plt.tight_layout()


# Save PDF
plt.savefig(
    'grouped_bar_Brain_HEK293T_THP1Macrophage_'
    'significant_fraction_p01.pdf',
    bbox_inches='tight'
)


# Save SVG
plt.savefig(
    'grouped_bar_Brain_HEK293T_THP1Macrophage_'
    'significant_fraction_p01.svg',
    bbox_inches='tight'
)


plt.show()


# =========================================================
# 4. Helper function: Benjamini-Hochberg FDR
# =========================================================
def bh_fdr(pvals):
    """
    Perform Benjamini-Hochberg FDR correction.
    """

    pvals = np.asarray(
        pvals,
        dtype=float
    )

    n = len(pvals)

    order = np.argsort(pvals)
    ranked_pvals = pvals[order]

    adjusted = (
        ranked_pvals
        * n
        / np.arange(1, n + 1)
    )

    # Enforce monotonicity
    adjusted = np.minimum.accumulate(
        adjusted[::-1]
    )[::-1]

    adjusted = np.clip(
        adjusted,
        0,
        1
    )

    output = np.empty_like(adjusted)
    output[order] = adjusted

    return output


# =========================================================
# 5. Chi-square test within each assay context
# =========================================================
chi2_results = []

residual_tables = {}
expected_tables = {}
observed_tables = {}


sig_label = f'p<{p_thresh:g}'
nonsig_label = f'p>={p_thresh:g}'


for sample_col in sample_cols:

    df_plot = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(
            cat_map.keys()
        )
    ].copy()

    df_plot = df_plot[
        ['Variant_Category', sample_col]
    ].copy()

    # Convert p-values to numeric
    df_plot[sample_col] = pd.to_numeric(
        df_plot[sample_col],
        errors='coerce'
    )

    # Remove missing p-values
    df_plot = df_plot.dropna(
        subset=[sample_col]
    ).copy()

    # Rename CRE categories
    df_plot['CRE_type'] = df_plot['Variant_Category'].map(
        cat_map
    )

    # Divide sequences into significant and non-significant groups
    df_plot['sig_group'] = np.where(
        df_plot[sample_col] < p_thresh,
        sig_label,
        nonsig_label
    )

    # -----------------------------------------------------
    # Create 5 x 2 contingency table
    # -----------------------------------------------------
    contingency = (
        pd.crosstab(
            df_plot['CRE_type'],
            df_plot['sig_group']
        )
        .reindex(
            index=chi2_plot_order,
            columns=[sig_label, nonsig_label],
            fill_value=0
        )
    )

    observed = contingency.values

    # Chi-square test
    chi2, pval, dof, expected = chi2_contingency(
        observed
    )

    expected_df = pd.DataFrame(
        expected,
        index=contingency.index,
        columns=contingency.columns
    )

    # Pearson standardized residuals
    residual_df = (
        contingency - expected_df
    ) / np.sqrt(expected_df)

    # Store tables
    observed_tables[sample_col] = contingency
    expected_tables[sample_col] = expected_df
    residual_tables[sample_col] = residual_df

    chi2_results.append({
        'sample': sample_col,
        'chi2': chi2,
        'dof': dof,
        'pvalue': pval,
        'min_expected': expected_df.min().min()
    })


# =========================================================
# 6. FDR correction across assay contexts
# =========================================================
chi2_df = pd.DataFrame(
    chi2_results
)

chi2_df['qvalue'] = bh_fdr(
    chi2_df['pvalue'].values
)

chi2_df = chi2_df.sort_values(
    'qvalue'
).reset_index(drop=True)


print("\nOverall chi-square tests using p < 0.1:")
print(chi2_df)


# Save overall chi-square results
chi2_df.to_csv(
    'chi_square_CRE_category_significance_p01.csv',
    index=False
)


# =========================================================
# 7. Print and save observed, expected, and residual tables
# =========================================================
for sample_col in sample_cols:

    print(
        f"\n==================== "
        f"{sample_col} "
        f"===================="
    )

    print("\nObserved table:")
    print(
        observed_tables[sample_col]
    )

    print("\nExpected table:")
    print(
        expected_tables[sample_col].round(2)
    )

    print("\nStandardized residuals:")
    print(
        residual_tables[sample_col].round(2)
    )

    # Save individual tables
    observed_tables[sample_col].to_csv(
        f'{sample_col}_observed_contingency_p01.csv'
    )

    expected_tables[sample_col].to_csv(
        f'{sample_col}_expected_contingency_p01.csv'
    )

    residual_tables[sample_col].to_csv(
        f'{sample_col}_standardized_residuals_p01.csv'
    )
# Out:
# Summary table using p < 0.1:
#               CRE_type  total_count  significant_count          sample  \
# 0          Immune CREs          571                126  THP1Macrophage
# 1        Neuronal CREs           86                  8  THP1Macrophage
# 2           Broad CREs          515                 84  THP1Macrophage
# 3           Glial CREs           53                  7  THP1Macrophage
# 4   Low ATAC Sequences          190                 34  THP1Macrophage
# 5          Immune CREs          571                105           Brain
# 6        Neuronal CREs           86                 19           Brain
# 7           Broad CREs          515                 76           Brain
# 8           Glial CREs           53                  6           Brain
# 9   Low ATAC Sequences          190                 34           Brain
# 10         Immune CREs          571                102         HEK293T
# 11       Neuronal CREs           86                 11         HEK293T
# 12          Broad CREs          515                 98         HEK293T
# 13          Glial CREs           53                  3         HEK293T
# 14  Low ATAC Sequences          190                 22         HEK293T
#
#     significant_fraction  significant_fraction_pct
# 0               0.220665                 22.066550
# 1               0.093023                  9.302326
# 2               0.163107                 16.310680
# 3               0.132075                 13.207547
# 4               0.178947                 17.894737
# 5               0.183888                 18.388792
# 6               0.220930                 22.093023
# 7               0.147573                 14.757282
# 8               0.113208                 11.320755
# 9               0.178947                 17.894737
# 10              0.178634                 17.863398
# 11              0.127907                 12.790698
# 12              0.190291                 19.029126
# 13              0.056604                  5.660377
# 14              0.115789                 11.578947
# Overall chi-square tests using p < 0.1:
#            sample       chi2  dof    pvalue  min_expected    qvalue
# 0  THP1Macrophage  12.376190    4  0.014762      9.701060  0.029022
# 1         HEK293T  11.745452    4  0.019348      8.839576  0.029022
# 2           Brain   5.525158    4  0.237527      8.989399  0.237527
#
# ==================== THP1Macrophage ====================
#
# Observed table:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences     34     156
# Immune CREs           126     445
# Broad CREs             84     431
# Neuronal CREs           8      78
# Glial CREs              7      46
#
# Expected table:
# sig_group            p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences   34.78  155.22
# Immune CREs         104.52  466.48
# Broad CREs           94.27  420.73
# Neuronal CREs        15.74   70.26
# Glial CREs            9.70   43.30
#
# Standardized residuals:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences  -0.13    0.06
# Immune CREs          2.10   -0.99
# Broad CREs          -1.06    0.50
# Neuronal CREs       -1.95    0.92
# Glial CREs          -0.87    0.41
#
# ==================== Brain ====================
#
# Observed table:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences     34     156
# Immune CREs           105     466
# Broad CREs             76     439
# Neuronal CREs          19      67
# Glial CREs              6      47
#
# Expected table:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences  32.23  157.77
# Immune CREs         96.85  474.15
# Broad CREs          87.35  427.65
# Neuronal CREs       14.59   71.41
# Glial CREs           8.99   44.01
#
# Standardized residuals:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences   0.31   -0.14
# Immune CREs          0.83   -0.37
# Broad CREs          -1.21    0.55
# Neuronal CREs        1.16   -0.52
# Glial CREs          -1.00    0.45
#
# ==================== HEK293T ====================
#
# Observed table:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences     22     168
# Immune CREs           102     469
# Broad CREs             98     417
# Neuronal CREs          11      75
# Glial CREs              3      50
#
# Expected table:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences  31.69  158.31
# Immune CREs         95.23  475.77
# Broad CREs          85.89  429.11
# Neuronal CREs       14.34   71.66
# Glial CREs           8.84   44.16
#
# Standardized residuals:
# sig_group           p<0.1  p>=0.1
# CRE_type
# Low ATAC Sequences  -1.72    0.77
# Immune CREs          0.69   -0.31
# Broad CREs           1.31   -0.58
# Neuronal CREs       -0.88    0.39
# Glial CREs          -1.96    0.88

# %%
# =========================================================
# CRE order
# Desired order from TOP to BOTTOM:
# Immune, Neuronal, Broad, Glial, Low ATAC
# =========================================================
legend_order = [
    'Immune CREs',
    'Neuronal CREs',
    'Broad CREs',
    'Glial CREs',
    'Low ATAC Sequences',
]

# Matplotlib stacks bars from bottom to top,
# so the plotting order must be reversed
stack_order = legend_order[::-1]


# =========================================================
# 1. build active-hit composition table
# =========================================================
all_active_summary = []

for sample_col in sample_cols:
    df_plot = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(cat_map.keys())
    ].copy()

    df_plot = df_plot[['Variant_Category', sample_col]].copy()
    df_plot[sample_col] = pd.to_numeric(
        df_plot[sample_col],
        errors='coerce'
    )
    df_plot = df_plot.dropna(subset=[sample_col]).copy()

    df_plot['CRE_type'] = df_plot['Variant_Category'].map(cat_map)
    df_plot = df_plot[
        df_plot['CRE_type'].isin(legend_order)
    ].copy()

    # active / significant
    df_plot['significant'] = df_plot[sample_col] <= p_thresh

    # only active hits
    df_active = df_plot[df_plot['significant']].copy()

    summary = (
        df_active.groupby('CRE_type')
        .size()
        .reindex(legend_order, fill_value=0)
        .reset_index(name='active_count')
    )

    summary['sample'] = sample_col

    total_active = summary['active_count'].sum()

    if total_active > 0:
        summary['active_fraction_within_sample'] = (
            summary['active_count'] / total_active
        )
    else:
        summary['active_fraction_within_sample'] = 0

    summary['active_fraction_pct'] = (
        summary['active_fraction_within_sample'] * 100
    )

    all_active_summary.append(summary)

active_comp_long = pd.concat(
    all_active_summary,
    axis=0,
    ignore_index=True
)

print(active_comp_long)


# =========================================================
# 2. reshape to wide for stacked bar plot
# =========================================================
plot_df = active_comp_long.pivot(
    index='sample',
    columns='CRE_type',
    values='active_fraction_pct'
).reindex(
    index=sample_cols,
    columns=legend_order
)

print(plot_df)


# =========================================================
# 3. plot 100% stacked bar plot
# =========================================================
sns.set(style='ticks', context='paper')

fig, ax = plt.subplots(figsize=(6.2, 5.2))

bottom = np.zeros(len(plot_df))
x = np.arange(len(plot_df.index))

bar_handles = {}

# Plot from bottom to top:
# Low ATAC -> Glial -> Broad -> Neuronal -> Immune
for cre_type in stack_order:
    vals = plot_df[cre_type].fillna(0).values

    bars = ax.bar(
        x,
        vals,
        bottom=bottom,
        color=color_map_cre[cre_type],
        edgecolor='black',
        linewidth=1.0,
        width=0.72,
        label=cre_type
    )

    bar_handles[cre_type] = bars[0]
    bottom += vals

ax.set_xticks(x)
ax.set_xticklabels(plot_df.index, fontsize=15)

ax.set_ylabel(
    'Composition of active CREs (%)',
    fontsize=18,
    labelpad=10
)
ax.set_xlabel('')
ax.set_ylim(0, 100)

ax.tick_params(
    axis='both',
    which='both',
    direction='in',
    top=True,
    right=True,
    labelsize=15,
    length=6,
    width=1.2
)

# Keep legend in the requested top-to-bottom order
ax.legend(
    handles=[bar_handles[x] for x in legend_order],
    labels=legend_order,
    title='',
    frameon=True,
    fontsize=13,
    bbox_to_anchor=(1.02, 1),
    loc='upper left'
)

sns.despine(top=False, right=False)
plt.tight_layout()

plt.savefig(
    'stacked_bar_active_CRE_composition_by_sample.pdf',
    bbox_inches='tight'
)

plt.savefig(
    'stacked_bar_active_CRE_composition_by_sample.svg',
    bbox_inches='tight'
)

plt.show()
# Out:
#               CRE_type  active_count          sample  \
# 0          Immune CREs           126  THP1Macrophage
# 1        Neuronal CREs             8  THP1Macrophage
# 2           Broad CREs            84  THP1Macrophage
# 3           Glial CREs             7  THP1Macrophage
# 4   Low ATAC Sequences            34  THP1Macrophage
# 5          Immune CREs           105           Brain
# 6        Neuronal CREs            19           Brain
# 7           Broad CREs            76           Brain
# 8           Glial CREs             6           Brain
# 9   Low ATAC Sequences            34           Brain
# 10         Immune CREs           102         HEK293T
# 11       Neuronal CREs            11         HEK293T
# 12          Broad CREs            98         HEK293T
# 13          Glial CREs             3         HEK293T
# 14  Low ATAC Sequences            22         HEK293T
#
#     active_fraction_within_sample  active_fraction_pct
# 0                        0.486486            48.648649
# 1                        0.030888             3.088803
# 2                        0.324324            32.432432
# 3                        0.027027             2.702703
# 4                        0.131274            13.127413
# 5                        0.437500            43.750000
# 6                        0.079167             7.916667
# 7                        0.316667            31.666667
# 8                        0.025000             2.500000
# 9                        0.141667            14.166667
# 10                       0.432203            43.220339
# 11                       0.046610             4.661017
# 12                       0.415254            41.525424
# 13                       0.012712             1.271186
# 14                       0.093220             9.322034
# CRE_type        Immune CREs  Neuronal CREs  Broad CREs  Glial CREs  \
# sample
# THP1Macrophage    48.648649       3.088803   32.432432    2.702703
# Brain             43.750000       7.916667   31.666667    2.500000
# HEK293T           43.220339       4.661017   41.525424    1.271186
#
# CRE_type        Low ATAC Sequences
# sample
# THP1Macrophage           13.127413
# Brain                    14.166667
# HEK293T                   9.322034

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# =========================================================
# Make text editable in Illustrator
# =========================================================
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['text.usetex'] = False
mpl.rcParams['font.family'] = 'Arial'

# =========================================================
# 1. settings
# =========================================================
# 把这里改成你之前图里所有想包括的细胞类型
sample_cols = [
    'THP1Macrophage',
    'Brain',
   #  'HMC3Cell',
     'HEK293T',

]

p_thresh = 0.05

cat_map = {
    'Low-ATAC': 'Low ATAC Sequences',
    'Immune-enriched': 'Immune CREs',
    'Broad': 'Broad CREs',
    'Neuronal-enriched': 'Neuronal CREs',
    'Glial-enriched': 'Glial CREs',
}

plot_order = [
    'Immune CREs',
    'Neuronal CREs',
    'Broad CREs',
    'Glial CREs',
    'Low ATAC Sequences',
]

# 颜色按 sample 分
color_map_sample = {
    'THP1Macrophage': '#ff2a60',
    'Brain': '#180aff',

     'HEK293T': '#00a087',
          #'HMC3Cell': '#f46e00',
}

# 如果 sample 比较多，也可以自动补颜色，避免报错
default_palette = sns.color_palette('tab10', n_colors=len(sample_cols))
for s, c in zip(sample_cols, default_palette):
    color_map_sample.setdefault(s, c)

# =========================================================
# 2. build composition table among active elements
# =========================================================
all_active_summary = []

for sample_col in sample_cols:
    if sample_col not in df_mpra_annotation_unique.columns:
        print(f"Warning: {sample_col} not found in dataframe, skipped.")
        continue

    df_plot = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(cat_map.keys())
    ].copy()

    df_plot = df_plot[['Variant_Category', sample_col]].copy()
    df_plot[sample_col] = pd.to_numeric(df_plot[sample_col], errors='coerce')
    df_plot = df_plot.dropna(subset=[sample_col]).copy()

    df_plot['CRE_type'] = df_plot['Variant_Category'].map(cat_map)
    df_plot = df_plot[df_plot['CRE_type'].isin(plot_order)].copy()

    # active/significant elements
    df_plot['significant'] = df_plot[sample_col] <= p_thresh
    df_active = df_plot[df_plot['significant']].copy()

    summary = (
        df_active.groupby('CRE_type')
        .size()
        .reindex(plot_order, fill_value=0)
        .reset_index(name='active_count')
    )

    summary['sample'] = sample_col

    total_active = summary['active_count'].sum()
    if total_active == 0:
        summary['active_fraction_within_sample'] = 0.0
    else:
        summary['active_fraction_within_sample'] = summary['active_count'] / total_active

    summary['active_fraction_pct'] = summary['active_fraction_within_sample'] * 100
    all_active_summary.append(summary)

active_comp_long = pd.concat(all_active_summary, axis=0, ignore_index=True)
print(active_comp_long)

# =========================================================
# 3. grouped barplot
# =========================================================
sns.set(style="ticks", context="paper")

# 细胞类型多了以后图自动加宽
fig_width = max(10, 1.2 * len(plot_order) + 1.2 * len(sample_cols))
fig, ax = plt.subplots(figsize=(fig_width, 5.2))

sns.barplot(
    data=active_comp_long,
    x='CRE_type',
    y='active_fraction_pct',
    hue='sample',
    order=plot_order,
    hue_order=[s for s in sample_cols if s in active_comp_long['sample'].unique()],
    palette=color_map_sample,
    edgecolor='black',
    ax=ax
)

for p in ax.patches:
    p.set_alpha(0.75)

# 可选：在柱子顶上标百分比
for p in ax.patches:
    height = p.get_height()
    if not np.isnan(height) and height > 0:
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + 0.5,
            f'{height:.1f}',
            ha='center',
            va='bottom',
            fontsize=10
        )

ax.set_xlabel('', fontsize=18)
ax.set_ylabel('Composition of active CREs (%)', fontsize=18, labelpad=10)
ax.set_xticklabels(plot_order, rotation=30, ha='right', fontsize=15)
ax.set_yticks(ax.get_yticks())
ax.set_yticklabels([f'{x:.0f}' for x in ax.get_yticks()], fontsize=15)

ax.tick_params(
    axis='both',
    which='both',
    direction='in',
    top=True,
    right=True,
    labelsize=15,
    length=6,
    width=1.2
)

legend = ax.legend(
    title='',
    frameon=True,
    fontsize=13,
    ncol=1 if len(sample_cols) <= 4 else 2,
    bbox_to_anchor=(1.02, 1),
    loc='upper left'
)

sns.despine(top=False, right=False)
plt.tight_layout()

plt.savefig(
    'grouped_bar_active_CRE_composition_all_samples.pdf',
    bbox_inches='tight'
)

plt.savefig(
    'grouped_bar_active_CRE_composition_all_samples.svg',
    bbox_inches='tight'
)

plt.show()

from scipy.stats import chi2_contingency
import pandas as pd
import numpy as np

# =========================================================
# compare distribution of significant hits across CRE types
# between THP1Macrophage and Brain
# =========================================================
sig_rows = []

for sample_col in sample_cols:
    df_test = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(cat_map.keys())
    ].copy()

    df_test = df_test[['Variant_Category', sample_col]].copy()
    df_test[sample_col] = pd.to_numeric(df_test[sample_col], errors='coerce')
    df_test = df_test.dropna(subset=[sample_col]).copy()

    df_test['CRE_type'] = df_test['Variant_Category'].map(cat_map)
    df_test = df_test[df_test['CRE_type'].isin(plot_order)].copy()
    df_test['sample'] = sample_col
    df_test['significant'] = df_test[sample_col] <= p_thresh

    # keep only significant hits
    df_sig = df_test[df_test['significant']].copy()
    sig_rows.append(df_sig[['sample', 'CRE_type']])

sig_df = pd.concat(sig_rows, axis=0, ignore_index=True)

# 2 x 5 table
cont_table = pd.crosstab(sig_df['sample'], sig_df['CRE_type'])
cont_table = cont_table.reindex(index=sample_cols, columns=plot_order, fill_value=0)

print("Contingency table of significant hits:")
print(cont_table)

chi2_stat, pval, dof, expected = chi2_contingency(cont_table)

expected_df = pd.DataFrame(expected, index=cont_table.index, columns=cont_table.columns)
residuals = (cont_table - expected_df) / np.sqrt(expected_df)

print("\nChi-square test of homogeneity")
print(f"chi2 = {chi2_stat:.4f}")
print(f"dof  = {dof}")
print(f"p    = {pval:.4e}")

print("\nExpected counts:")
print(expected_df.round(2))

print("\nPearson residuals:")
print(residuals.round(2))
# Out:
#               CRE_type  active_count          sample  \
# 0          Immune CREs            96  THP1Macrophage
# 1        Neuronal CREs             7  THP1Macrophage
# 2           Broad CREs            56  THP1Macrophage
# 3           Glial CREs             4  THP1Macrophage
# 4   Low ATAC Sequences            25  THP1Macrophage
# 5          Immune CREs            71           Brain
# 6        Neuronal CREs            15           Brain
# 7           Broad CREs            55           Brain
# 8           Glial CREs             5           Brain
# 9   Low ATAC Sequences            25           Brain
# 10         Immune CREs            81         HEK293T
# 11       Neuronal CREs             9         HEK293T
# 12          Broad CREs            76         HEK293T
# 13          Glial CREs             2         HEK293T
# 14  Low ATAC Sequences            15         HEK293T
#
#     active_fraction_within_sample  active_fraction_pct
# 0                        0.510638            51.063830
# 1                        0.037234             3.723404
# 2                        0.297872            29.787234
# 3                        0.021277             2.127660
# 4                        0.132979            13.297872
# 5                        0.415205            41.520468
# 6                        0.087719             8.771930
# 7                        0.321637            32.163743
# 8                        0.029240             2.923977
# 9                        0.146199            14.619883
# 10                       0.442623            44.262295
# 11                       0.049180             4.918033
# 12                       0.415301            41.530055
# 13                       0.010929             1.092896
# 14                       0.081967             8.196721
# /tmp/ipykernel_3539731/4120470827.py:145: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(plot_order, rotation=30, ha='right', fontsize=15)
# Contingency table of significant hits:
# CRE_type        Immune CREs  Neuronal CREs  Broad CREs  Glial CREs  \
# sample
# THP1Macrophage           96              7          56           4
# Brain                    71             15          55           5
# HEK293T                  81              9          76           2
#
# CRE_type        Low ATAC Sequences
# sample
# THP1Macrophage                  25
# Brain                           25
# HEK293T                         15
#
# Chi-square test of homogeneity
# chi2 = 15.2442
# dof  = 8
# p    = 5.4568e-02
#
# Expected counts:
# CRE_type        Immune CREs  Neuronal CREs  Broad CREs  Glial CREs  \
# sample
# THP1Macrophage        86.02          10.75       64.86        3.82
# Brain                 78.24           9.78       59.00        3.47
# HEK293T               83.73          10.47       63.14        3.71
#
# CRE_type        Low ATAC Sequences
# sample
# THP1Macrophage               22.55
# Brain                        20.51
# HEK293T                      21.95
#
# Pearson residuals:
# CRE_type        Immune CREs  Neuronal CREs  Broad CREs  Glial CREs  \
# sample
# THP1Macrophage         1.08          -1.14       -1.10        0.09
# Brain                 -0.82           1.67       -0.52        0.82
# HEK293T               -0.30          -0.45        1.62       -0.89
#
# CRE_type        Low ATAC Sequences
# sample
# THP1Macrophage                0.52
# Brain                         0.99
# HEK293T                      -1.48

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# =========================================================
# 1. settings
# =========================================================
sample_cols = ['Brain', 'THP1Macrophage']
p_thresh = 0.05

cat_map = {
    'Low-ATAC': 'Low ATAC Sequences',
    'Immune-enriched': 'Immune CREs',
    'Broad': 'Broad CREs',
    'Neuronal-enriched': 'Neuronal CREs',
    'Glial-enriched': 'Glial CREs',
}

plot_order = [
    'Low ATAC Sequences',
    'Immune CREs',
    'Broad CREs',
    'Neuronal CREs',
    'Glial CREs',
]

sig_order = ['p < 0.05', 'p > 0.05']

color_map_sig = {
    'p < 0.05': '#4C78A8',
    'p > 0.05': '#D9D9D9',
}

sns.set(style="ticks", context="paper")

# =========================================================
# 2. make one grouped bar plot per sample
# =========================================================
for sample_col in sample_cols:
    df_plot = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(cat_map.keys())
    ].copy()

    df_plot = df_plot[['Variant_Category', sample_col]].copy()
    df_plot[sample_col] = pd.to_numeric(df_plot[sample_col], errors='coerce')
    df_plot = df_plot.dropna(subset=[sample_col]).copy()

    df_plot['CRE_type'] = df_plot['Variant_Category'].map(cat_map)
    df_plot['sig_group'] = np.where(df_plot[sample_col] <= p_thresh, 'p < 0.05', 'p > 0.05')

    summary = (
        df_plot.groupby(['CRE_type', 'sig_group'])
        .size()
        .reset_index(name='count')
    )

    total_per_type = (
        df_plot.groupby('CRE_type')
        .size()
        .reindex(plot_order)
        .rename('total_count')
        .reset_index()
    )

    summary = summary.merge(total_per_type, on='CRE_type', how='left')
    summary['fraction_pct'] = summary['count'] / summary['total_count'] * 100

    # make sure all CRE_type x sig_group combinations exist
    full_index = pd.MultiIndex.from_product(
        [plot_order, sig_order],
        names=['CRE_type', 'sig_group']
    )
    summary = (
        summary.set_index(['CRE_type', 'sig_group'])
        .reindex(full_index, fill_value=0)
        .reset_index()
    )

    fig, ax = plt.subplots(figsize=(7.5, 5.2))

    sns.barplot(
        data=summary,
        x='CRE_type',
        y='fraction_pct',
        hue='sig_group',
        order=plot_order,
        hue_order=sig_order,
        palette=color_map_sig,
        edgecolor='black',
        ax=ax
    )

    # add labels
    for p in ax.patches:
        height = p.get_height()
        if not np.isnan(height) and height > 0:
            ax.text(
                p.get_x() + p.get_width() / 2,
                height + 0.8,
                f'{height:.1f}',
                ha='center',
                va='bottom',
                fontsize=9
            )

    ax.set_xlabel('')
    ax.set_ylabel('Fraction within CRE type (%)', fontsize=13)
    ax.set_title(sample_col, fontsize=15)
    ax.set_xticklabels(plot_order, rotation=30, ha='right')
    ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

    plt.legend(title='MPRA significance', frameon=True)
    sns.despine(top=False, right=False)
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_3539731/1333554890.py:110: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(plot_order, rotation=30, ha='right')
# /tmp/ipykernel_3539731/1333554890.py:110: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(plot_order, rotation=30, ha='right')

# %%
df_mpra_annotation_unique.iloc[:,0:15].columns
# Out:
# Index(['THP1Macrophage', 'Brain', 'HEK293T', 'Cortex', 'Striatum',
#        'Hippocampus', 'HMC3Cell', 'HMC3_IFNB', 'HMC3_IFNG', 'HMC3_Naive',
#        'HMC3_LPSIFNG', 'THP1Monocyte', 'THP1_Naive', 'THP1_IFNG', 'THP1_IFNB'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# =========================================================
# 1. settings
# =========================================================
sample_cols = ['THP1Macrophage', 'Brain','Cortex','Striatum','Hippocampus','THP1_Naive', 'THP1_IFNG', 'THP1_IFNB', 'THP1_LPSIFNG','HMC3_Naive','HMC3_IFNB','HMC3_IFNG',"HMC3_LPSIFNG","HEK293T"]
p_thresh = 0.05


cat_map = {
    'Low-ATAC': 'Low ATAC Sequences',
    'Immune-enriched': 'Immune CREs',
    'Broad': 'Broad CREs',
    'Neuronal-enriched': 'Neuronal CREs',
    'Glial-enriched': 'Glial CREs',
}

plot_order = [
    'Low ATAC Sequences',
    'Immune CREs',
    'Broad CREs',
    'Neuronal CREs',
    'Glial CREs',
]

# =========================================================
# 2. helper: BH-FDR
# =========================================================
def bh_fdr(pvals):
    pvals = np.asarray(pvals, dtype=float)
    n = len(pvals)
    order = np.argsort(pvals)
    ranked = pvals[order]
    q = ranked * n / np.arange(1, n + 1)
    q = np.minimum.accumulate(q[::-1])[::-1]
    q = np.clip(q, 0, 1)
    out = np.empty_like(q)
    out[order] = q
    return out

# =========================================================
# 3. chi-square test within each sample
# =========================================================
chi2_results = []
residual_tables = {}
expected_tables = {}
observed_tables = {}

for sample_col in sample_cols:
    df_plot = df_mpra_annotation_unique[
        df_mpra_annotation_unique['Variant_Category'].isin(cat_map.keys())
    ].copy()

    df_plot = df_plot[['Variant_Category', sample_col]].copy()
    df_plot[sample_col] = pd.to_numeric(df_plot[sample_col], errors='coerce')
    df_plot = df_plot.dropna(subset=[sample_col]).copy()

    df_plot['CRE_type'] = df_plot['Variant_Category'].map(cat_map)
    df_plot['sig_group'] = np.where(df_plot[sample_col] < p_thresh, 'p<0.05', 'p>=0.05')

    # 5 x 2 contingency table
    contingency = (
        pd.crosstab(df_plot['CRE_type'], df_plot['sig_group'])
        .reindex(index=plot_order, columns=['p<0.05', 'p>=0.05'], fill_value=0)
    )

    observed = contingency.values
    chi2, pval, dof, expected = chi2_contingency(observed)

    expected_df = pd.DataFrame(
        expected,
        index=contingency.index,
        columns=contingency.columns
    )

    residual_df = (contingency - expected_df) / np.sqrt(expected_df)

    observed_tables[sample_col] = contingency
    expected_tables[sample_col] = expected_df
    residual_tables[sample_col] = residual_df

    chi2_results.append({
        'sample': sample_col,
        'chi2': chi2,
        'dof': dof,
        'pvalue': pval,
        'min_expected': expected_df.min().min()
    })

chi2_df = pd.DataFrame(chi2_results)
chi2_df['qvalue'] = bh_fdr(chi2_df['pvalue'].values)

print("\nOverall chi-square tests:")
print(chi2_df.sort_values('qvalue'))

for sample_col in sample_cols:
    print(f"\n==================== {sample_col} ====================")
    print("\nObserved table:")
    print(observed_tables[sample_col])

    print("\nExpected table:")
    print(expected_tables[sample_col].round(2))

    print("\nStandardized residuals:")
    print(residual_tables[sample_col].round(2))
# Out:
# Overall chi-square tests:
#             sample       chi2  dof    pvalue  min_expected    qvalue
# 9       HMC3_Naive  30.990469    4  0.000003      8.390106  0.000043
# 12    HMC3_LPSIFNG  22.259803    4  0.000178      2.322261  0.001245
# 7        THP1_IFNB  13.473569    4  0.009179      8.352650  0.032128
# 11       HMC3_IFNG  14.027922    4  0.007206      4.120141  0.032128
# 10       HMC3_IFNB  11.198873    4  0.024418      2.060071  0.041062
# 0   THP1Macrophage  12.259905    4  0.015520      7.041696  0.041062
# 5       THP1_Naive  11.163977    4  0.024782      7.004240  0.041062
# 6        THP1_IFNG  11.400142    4  0.022417      7.528622  0.041062
# 13         HEK293T  11.014890    4  0.026397      6.854417  0.041062
# 2           Cortex  10.356315    4  0.034835      4.195053  0.048769
# 8     THP1_LPSIFNG   4.869132    4  0.300991      5.019081  0.383079
# 3         Striatum   4.382438    4  0.356716      3.895406  0.416168
# 1            Brain   3.902259    4  0.419395      6.404947  0.451656
# 4      Hippocampus   2.133202    4  0.711275      6.180212  0.711275
#
# ==================== THP1Macrophage ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      25      165
# Immune CREs             96      475
# Broad CREs              56      459
# Neuronal CREs            7       79
# Glial CREs               4       49
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   25.24   164.76
# Immune CREs          75.86   495.14
# Broad CREs           68.42   446.58
# Neuronal CREs        11.43    74.57
# Glial CREs            7.04    45.96
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   -0.05     0.02
# Immune CREs           2.31    -0.90
# Broad CREs           -1.50     0.59
# Neuronal CREs        -1.31     0.51
# Glial CREs           -1.15     0.45
#
# ==================== Brain ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      25      165
# Immune CREs             71      500
# Broad CREs              55      460
# Neuronal CREs           15       71
# Glial CREs               5       48
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   22.96   167.04
# Immune CREs          69.00   502.00
# Broad CREs           62.24   452.76
# Neuronal CREs        10.39    75.61
# Glial CREs            6.40    46.60
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    0.43    -0.16
# Immune CREs           0.24    -0.09
# Broad CREs           -0.92     0.34
# Neuronal CREs         1.43    -0.53
# Glial CREs           -0.56     0.21
#
# ==================== Cortex ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      22      168
# Immune CREs             41      530
# Broad CREs              35      480
# Neuronal CREs           12       74
# Glial CREs               2       51
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   15.04   174.96
# Immune CREs          45.20   525.80
# Broad CREs           40.76   474.24
# Neuronal CREs         6.81    79.19
# Glial CREs            4.20    48.80
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    1.80    -0.53
# Immune CREs          -0.62     0.18
# Broad CREs           -0.90     0.26
# Neuronal CREs         1.99    -0.58
# Glial CREs           -1.07     0.31
#
# ==================== Striatum ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      17      173
# Immune CREs             41      530
# Broad CREs              36      479
# Neuronal CREs            9       77
# Glial CREs               1       52
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   13.96   176.04
# Immune CREs          41.97   529.03
# Broad CREs           37.85   477.15
# Neuronal CREs         6.32    79.68
# Glial CREs            3.90    49.10
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    0.81    -0.23
# Immune CREs          -0.15     0.04
# Broad CREs           -0.30     0.08
# Neuronal CREs         1.07    -0.30
# Glial CREs           -1.47     0.41
#
# ==================== Hippocampus ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      21      169
# Immune CREs             71      500
# Broad CREs              55      460
# Neuronal CREs           13       73
# Glial CREs               5       48
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   22.16   167.84
# Immune CREs          66.58   504.42
# Broad CREs           60.05   454.95
# Neuronal CREs        10.03    75.97
# Glial CREs            6.18    46.82
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   -0.25     0.09
# Immune CREs           0.54    -0.20
# Broad CREs           -0.65     0.24
# Neuronal CREs         0.94    -0.34
# Glial CREs           -0.47     0.17
#
# ==================== THP1_Naive ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      26      164
# Immune CREs             94      477
# Broad CREs              56      459
# Neuronal CREs            7       79
# Glial CREs               4       49
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   25.11   164.89
# Immune CREs          75.46   495.54
# Broad CREs           68.06   446.94
# Neuronal CREs        11.37    74.63
# Glial CREs            7.00    46.00
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    0.18    -0.07
# Immune CREs           2.13    -0.83
# Broad CREs           -1.46     0.57
# Neuronal CREs        -1.29     0.51
# Glial CREs           -1.14     0.44
#
# ==================== THP1_IFNG ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      27      163
# Immune CREs            101      470
# Broad CREs              60      455
# Neuronal CREs            7       79
# Glial CREs               6       47
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   26.99   163.01
# Immune CREs          81.11   489.89
# Broad CREs           73.16   441.84
# Neuronal CREs        12.22    73.78
# Glial CREs            7.53    45.47
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    0.00    -0.00
# Immune CREs           2.21    -0.90
# Broad CREs           -1.54     0.63
# Neuronal CREs        -1.49     0.61
# Glial CREs           -0.56     0.23
#
# ==================== THP1_IFNB ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      32      158
# Immune CREs            111      460
# Broad CREs              67      448
# Neuronal CREs            7       79
# Glial CREs               6       47
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   29.94   160.06
# Immune CREs          89.99   481.01
# Broad CREs           81.16   433.84
# Neuronal CREs        13.55    72.45
# Glial CREs            8.35    44.65
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    0.38    -0.16
# Immune CREs           2.22    -0.96
# Broad CREs           -1.57     0.68
# Neuronal CREs        -1.78     0.77
# Glial CREs           -0.81     0.35
#
# ==================== THP1_LPSIFNG ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      15      175
# Immune CREs             61      510
# Broad CREs              51      464
# Neuronal CREs            4       82
# Glial CREs               3       50
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   17.99   172.01
# Immune CREs          54.07   516.93
# Broad CREs           48.77   466.23
# Neuronal CREs         8.14    77.86
# Glial CREs            5.02    47.98
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   -0.71     0.23
# Immune CREs           0.94    -0.30
# Broad CREs            0.32    -0.10
# Neuronal CREs        -1.45     0.47
# Glial CREs           -0.90     0.29
#
# ==================== HMC3_Naive ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      51      139
# Immune CREs             87      484
# Broad CREs              57      458
# Neuronal CREs           21       65
# Glial CREs               8       45
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   30.08   159.92
# Immune CREs          90.39   480.61
# Broad CREs           81.53   433.47
# Neuronal CREs        13.61    72.39
# Glial CREs            8.39    44.61
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    3.81    -1.65
# Immune CREs          -0.36     0.15
# Broad CREs           -2.72     1.18
# Neuronal CREs         2.00    -0.87
# Glial CREs           -0.13     0.06
#
# ==================== HMC3_IFNB ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences       8      182
# Immune CREs             25      546
# Broad CREs              14      501
# Neuronal CREs            8       78
# Glial CREs               0       53
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    7.39   182.61
# Immune CREs          22.19   548.81
# Broad CREs           20.02   494.98
# Neuronal CREs         3.34    82.66
# Glial CREs            2.06    50.94
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    0.23    -0.05
# Immune CREs           0.60    -0.12
# Broad CREs           -1.34     0.27
# Neuronal CREs         2.55    -0.51
# Glial CREs           -1.44     0.29
#
# ==================== HMC3_IFNG ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      26      164
# Immune CREs             45      526
# Broad CREs              29      486
# Neuronal CREs            8       78
# Glial CREs               2       51
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   14.77   175.23
# Immune CREs          44.39   526.61
# Broad CREs           40.04   474.96
# Neuronal CREs         6.69    79.31
# Glial CREs            4.12    48.88
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    2.92    -0.85
# Immune CREs           0.09    -0.03
# Broad CREs           -1.74     0.51
# Neuronal CREs         0.51    -0.15
# Glial CREs           -1.04     0.30
#
# ==================== HMC3_LPSIFNG ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      18      172
# Immune CREs             25      546
# Broad CREs              12      503
# Neuronal CREs            7       79
# Glial CREs               0       53
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    8.33   181.67
# Immune CREs          25.02   545.98
# Broad CREs           22.57   492.43
# Neuronal CREs         3.77    82.23
# Glial CREs            2.32    50.68
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences    3.35    -0.72
# Immune CREs          -0.00     0.00
# Broad CREs           -2.22     0.48
# Neuronal CREs         1.66    -0.36
# Glial CREs           -1.52     0.33
#
# ==================== HEK293T ====================
#
# Observed table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences      15      175
# Immune CREs             81      490
# Broad CREs              76      439
# Neuronal CREs            9       77
# Glial CREs               2       51
#
# Expected table:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   24.57   165.43
# Immune CREs          73.85   497.15
# Broad CREs           66.60   448.40
# Neuronal CREs        11.12    74.88
# Glial CREs            6.85    46.15
#
# Standardized residuals:
# sig_group           p<0.05  p>=0.05
# CRE_type
# Low ATAC Sequences   -1.93     0.74
# Immune CREs           0.83    -0.32
# Broad CREs            1.15    -0.44
# Neuronal CREs        -0.64     0.25
# Glial CREs           -1.85     0.71

# %%
df_mpra_annotation_unique
# Out:
#                                                     THP1Macrophage     Brain  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...        0.001765  0.188590
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...        0.837334  0.639903
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...        0.054455  0.150777
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...        0.973911  0.821705
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...        0.954601  0.969509
# ...                                                            ...       ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...        0.333542  0.933314
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...        0.295088  0.856594
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...        0.960112  0.830979
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...        0.624618  0.071043
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...        0.279954  0.286859
#
#                                                      HEK293T    Cortex  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  0.010447  0.322655
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  0.983199  0.799595
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  0.028097  0.814269
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  0.930123  0.583045
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  0.926855  0.964454
# ...                                                      ...       ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  0.813532  0.916938
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  0.582507  0.916202
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  0.686254  0.925415
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  0.075736  0.049827
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  0.425383  0.559209
#
#                                                     Striatum  Hippocampus  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  0.519032     0.316151
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  0.673714     0.776677
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  0.681148     0.512242
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  0.522951     0.684094
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  0.933899     0.971509
# ...                                                      ...          ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  0.946217     0.914545
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  0.769515     0.793902
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  0.892002     0.639602
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  0.078954     0.133840
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  0.508043     0.562885
#
#                                                     HMC3Cell  HMC3_IFNB  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  0.150031   0.156222
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  0.958347   0.951750
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  0.243805   0.394417
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  0.907126   0.917069
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  0.867091   0.869490
# ...                                                      ...        ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  0.568131   0.675672
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  0.258771   0.323283
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  0.597486   0.635336
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  0.125426   0.201565
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  0.163182   0.220223
#
#                                                     HMC3_IFNG  HMC3_Naive  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...   0.086246    0.042867
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...   0.972169    0.970266
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...   0.161525    0.066196
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...   0.856296    0.928403
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...   0.842528    0.887963
# ...                                                       ...         ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...   0.506487    0.450971
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...   0.166683    0.145644
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...   0.611141    0.527484
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...   0.086813    0.052988
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...   0.085241    0.076773
#
#                                                     ...  VIP  VIP_1  VIP_2  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...  ...    1      1      1
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...  ...    0      0      0
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...  ...    1      1      1
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...  ...    0      0      0
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...  ...    0      0      0
# ...                                                 ...  ...    ...    ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...  ...    0      0      0
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...  ...    0      0      0
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...  ...    0      0      0
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...  ...    0      0      0
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...  ...    0      0      0
#
#                                                     VIP_3  VIP_4  VIP_5 VIP_6  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...      1      1      1     1
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...      0      0      0     0
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...      1      1      1     1
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...      0      0      0     0
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...      0      0      0     0
# ...                                                   ...    ...    ...   ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...      0      0      0     0
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...      0      0      0     0
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...      0      0      0     0
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...      0      0      0     0
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...      0      0      0     0
#
#                                                    VIP_7   Variant_Category  \
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...     1              Broad
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...     0           Low-ATAC
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...     1              Broad
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...     0    Immune-enriched
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...     0              Broad
# ...                                                  ...                ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...     0    Immune-enriched
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...     0    Immune-enriched
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...     0    Immune-enriched
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...     0    Immune-enriched
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...     0  Neuronal-enriched
#
#                                                    absoluate_distance_to_tss
# alt:cg03073402:SNPCENTER:chr19:42927676:C:G:429...                      1547
# alt:cg03169557:SNPCENTER:chr16:89598950:C:G:895...                     28082
# alt:cg05030077:SNPCENTER:chr16:2255199:C:G:2255...                       950
# alt:cg05066959:SNPCENTER:chr8:41519308:C:G:4151...                       799
# alt:cg05228284:SNPCENTER:chr19:2720847:C:G:2720...                       523
# ...                                                                      ...
# ref:rs9281938:PEAKCENTER:chr6:32576282:T:TA:325...                     18657
# ref:rs9304646:PEAKCENTER:chr19:44947151:T:A:449...                      1116
# ref:rs9357546:PEAKCENTER:chr6:47549495:C:T:4754...                     19137
# ref:rs983392:PEAKCENTER:chr11:59923508:A:G:5992...                      4787
# ref:rs9912783:PEAKCENTER:chr17:61522705:C:T:615...                      1010
#
# [1415 rows x 352 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import chi2_contingency

# =========================================================
# Make text editable in Illustrator
# =========================================================
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['text.usetex'] = False
mpl.rcParams['font.family'] = 'Arial'

# =========================================================
# 1. settings
# =========================================================
p_thresh = 0.05
brain_col = 'Brain'
immune_col = 'THP1Macrophage'

row_order = ['Immune', 'Brain', 'Non-specific']
col_order = [
    'Immune-enriched',
    'Neuronal-enriched',
    'Broad',
    'Glial-enriched',
    'Low-ATAC'
]

# =========================================================
# 2. prepare dataframe
# =========================================================
df_plot = df_mpra_annotation_unique.copy()

df_plot = df_plot[
    df_plot['Variant_Category'].isin(col_order)
].copy()

df_plot[brain_col] = pd.to_numeric(df_plot[brain_col], errors='coerce')
df_plot[immune_col] = pd.to_numeric(df_plot[immune_col], errors='coerce')
df_plot = df_plot.dropna(subset=[brain_col, immune_col]).copy()

# =========================================================
# 3. define MPRA CRE cluster
# =========================================================
brain_sig = df_plot[brain_col] <= p_thresh
immune_sig = df_plot[immune_col] <= p_thresh

df_plot['MPRA_CRE_Cluster'] = np.select(
    [
        immune_sig & ~brain_sig,
        brain_sig & ~immune_sig,
        brain_sig & immune_sig,
    ],
    [
        'Immune',
        'Brain',
        'Non-specific',
    ],
    default='Not-significant'
)

# 去掉两边都不显著的
df_plot = df_plot.dropna(subset=['MPRA_CRE_Cluster']).copy()

# 直接保留原始 ATAC 分类
df_plot['ATAC_CRE_Cluster'] = df_plot['Variant_Category']

# =========================================================
# 4. contingency table
# =========================================================
contingency = pd.crosstab(
    df_plot['MPRA_CRE_Cluster'],
    df_plot['ATAC_CRE_Cluster']
).reindex(index=row_order, columns=col_order, fill_value=0)

print("Contingency table:")
print(contingency)

# =========================================================
# 5. chi-square test
# =========================================================
chi2, pval, dof, expected = chi2_contingency(contingency)

expected_df = pd.DataFrame(
    expected,
    index=contingency.index,
    columns=contingency.columns
)

obs_over_exp = contingency / expected_df

print("\nExpected table:")
print(expected_df)

print("\nObserved / Expected:")
print(obs_over_exp)

# =========================================================
# 6. plot heatmap
# =========================================================
sns.set(style="white", context="paper")

fig, ax = plt.subplots(figsize=(8,6), dpi=300)

hm = sns.heatmap(
    obs_over_exp,
    cmap='RdBu_r',
    center=1.0,
    annot=True,
    fmt='.2f',
    linewidths=0,
    cbar=True,
    annot_kws={'fontsize': 16},
    ax=ax
)

ax.set_xlabel('ATAC CRE Cluster', fontsize=20, labelpad=12)
ax.set_ylabel('MPRA CRE Cluster', fontsize=20, labelpad=12)

ax.set_xticklabels(ax.get_xticklabels(), rotation=35, ha='right', fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(), rotation=90, va='center', fontsize=16)

ax.set_title(f'(Chi-square p-value: {pval:.3e})', fontsize=24, pad=16)

ax.tick_params(
    axis='both',
    which='both',
    direction='out',
    length=6,
    width=1.5,
    labelsize=15
)

# colorbar
cbar = hm.collections[0].colorbar
cbar.ax.tick_params(labelsize=14, width=1.2, length=5)
cbar.ax.set_title('Observed\nExpected', fontsize=16, pad=14)

plt.tight_layout()

plt.savefig(
    'chi_square_obs_over_exp_heatmap_5categories.pdf',
    bbox_inches='tight'
)
plt.savefig(
    'chi_square_obs_over_exp_heatmap_5categories.svg',
    bbox_inches='tight'
)

plt.show()
# Out:
# Contingency table:
# ATAC_CRE_Cluster  Immune-enriched  Neuronal-enriched  Broad  Glial-enriched  \
# MPRA_CRE_Cluster
# Immune                         80                  3     41               3
# Brain                          55                 11     40               4
# Non-specific                   16                  4     15               1
#
# ATAC_CRE_Cluster  Low-ATAC
# MPRA_CRE_Cluster
# Immune                  22
# Brain                   22
# Non-specific             3
#
# Expected table:
# ATAC_CRE_Cluster  Immune-enriched  Neuronal-enriched  Broad  Glial-enriched  \
# MPRA_CRE_Cluster
# Immune                  70.309375            8.38125   44.7           3.725
# Brain                   62.287500            7.42500   39.6           3.300
# Non-specific            18.403125            2.19375   11.7           0.975
#
# ATAC_CRE_Cluster   Low-ATAC
# MPRA_CRE_Cluster
# Immune            21.884375
# Brain             19.387500
# Non-specific       5.728125
#
# Observed / Expected:
# ATAC_CRE_Cluster  Immune-enriched  Neuronal-enriched     Broad  \
# MPRA_CRE_Cluster
# Immune                   1.137828           0.357942  0.917226
# Brain                    0.883002           1.481481  1.010101
# Non-specific             0.869418           1.823362  1.282051
#
# ATAC_CRE_Cluster  Glial-enriched  Low-ATAC
# MPRA_CRE_Cluster
# Immune                  0.805369  1.005283
# Brain                   1.212121  1.134752
# Non-specific            1.025641  0.523732

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import chi2_contingency, fisher_exact, norm
from statsmodels.stats.multitest import multipletests

# =========================================================
# Make text editable in Illustrator
# =========================================================
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['text.usetex'] = False
mpl.rcParams['font.family'] = 'Arial'

# =========================================================
# 1. settings
# =========================================================
p_thresh = 0.05
brain_col = 'Brain'
immune_col = 'THP1Macrophage'

row_order = ['Immune', 'Brain', 'Non-specific']
col_order = [
    'Immune-enriched',
    'Neuronal-enriched',
    'Broad',
    'Glial-enriched',
    'Low-ATAC'
]

# Pre-specified biological hypotheses for 2x2 Fisher tests
# 只保留你事先有明确生物学理由的比较，避免 reviewer 觉得是 post hoc fishing
pre_specified_tests = [
    ('Immune', 'Immune-enriched'),
    ('Brain', 'Neuronal-enriched'),
    ('Brain', 'Glial-enriched'),
    # 如果你有强理由，也可加：
    # ('Non-specific', 'Broad'),
]

n_perm = 10000
random_seed = 1

# =========================================================
# 2. prepare dataframe
# =========================================================
df_plot = df_mpra_annotation_unique.copy()

df_plot = df_plot[
    df_plot['Variant_Category'].isin(col_order)
].copy()

df_plot[brain_col] = pd.to_numeric(df_plot[brain_col], errors='coerce')
df_plot[immune_col] = pd.to_numeric(df_plot[immune_col], errors='coerce')
df_plot = df_plot.dropna(subset=[brain_col, immune_col]).copy()

# =========================================================
# 3. define MPRA CRE cluster
# =========================================================
brain_sig = df_plot[brain_col] <= p_thresh
immune_sig = df_plot[immune_col] <= p_thresh

df_plot['MPRA_CRE_Cluster'] = np.select(
    [
        immune_sig & ~brain_sig,
        brain_sig & ~immune_sig,
        brain_sig & immune_sig,
    ],
    [
        'Immune',
        'Brain',
        'Non-specific',
    ],
    default='Not-significant'
)

# 真正去掉两边都不显著的
df_plot = df_plot[df_plot['MPRA_CRE_Cluster'] != 'Not-significant'].copy()

# 保留原始 ATAC 分类
df_plot['ATAC_CRE_Cluster'] = df_plot['Variant_Category']

# =========================================================
# 4. contingency table
# =========================================================
contingency = pd.crosstab(
    pd.Categorical(df_plot['MPRA_CRE_Cluster'], categories=row_order),
    pd.Categorical(df_plot['ATAC_CRE_Cluster'], categories=col_order)
).reindex(index=row_order, columns=col_order, fill_value=0)

print("Contingency table:")
print(contingency)

# =========================================================
# 5. overall association tests
# =========================================================
# Pearson chi-square
chi2, pval_chi2, dof, expected = chi2_contingency(contingency, correction=False)

# Likelihood-ratio test (G-test)
g_stat, pval_g, dof_g, expected_g = chi2_contingency(
    contingency, correction=False, lambda_='log-likelihood'
)

expected_df = pd.DataFrame(
    expected,
    index=contingency.index,
    columns=contingency.columns
)

obs_over_exp = contingency / expected_df

# Effect size: Cramer's V
n_total = contingency.values.sum()
r, k = contingency.shape
cramers_v = np.sqrt(chi2 / (n_total * min(r - 1, k - 1)))

print("\nExpected table:")
print(expected_df.round(3))

print("\nObserved / Expected:")
print(obs_over_exp.round(3))

print(f"\nPearson chi-square:")
print(f"  chi2 = {chi2:.4f}")
print(f"  dof  = {dof}")
print(f"  p    = {pval_chi2:.4g}")

print(f"\nG-test:")
print(f"  G    = {g_stat:.4f}")
print(f"  dof  = {dof_g}")
print(f"  p    = {pval_g:.4g}")

print(f"\nCramer's V = {cramers_v:.4f}")

# =========================================================
# 6. permutation test for independence
# =========================================================
def permutation_chi2_test(df_input, row_order, col_order, n_perm=10000, seed=1):
    rng = np.random.default_rng(seed)

    mpra = df_input['MPRA_CRE_Cluster'].to_numpy()
    atac = df_input['ATAC_CRE_Cluster'].to_numpy()

    obs_tab = pd.crosstab(
        pd.Categorical(mpra, categories=row_order),
        pd.Categorical(atac, categories=col_order)
    ).reindex(index=row_order, columns=col_order, fill_value=0)

    chi2_obs, _, _, _ = chi2_contingency(obs_tab, correction=False)

    chi2_perm = np.empty(n_perm, dtype=float)

    for i in range(n_perm):
        atac_perm = rng.permutation(atac)
        perm_tab = pd.crosstab(
            pd.Categorical(mpra, categories=row_order),
            pd.Categorical(atac_perm, categories=col_order)
        ).reindex(index=row_order, columns=col_order, fill_value=0)

        chi2_perm[i] = chi2_contingency(perm_tab, correction=False)[0]

    p_perm = (np.sum(chi2_perm >= chi2_obs) + 1) / (n_perm + 1)
    return chi2_obs, p_perm, chi2_perm

chi2_obs_perm, pval_perm, chi2_perm_dist = permutation_chi2_test(
    df_plot,
    row_order=row_order,
    col_order=col_order,
    n_perm=n_perm,
    seed=random_seed
)

print(f"\nPermutation chi-square:")
print(f"  observed chi2 = {chi2_obs_perm:.4f}")
print(f"  p_perm        = {pval_perm:.4g}")

# =========================================================
# 7. adjusted standardized residuals
# =========================================================
obs = contingency.values.astype(float)
exp = expected_df.values.astype(float)
n = obs.sum()

row_prop = obs.sum(axis=1, keepdims=True) / n
col_prop = obs.sum(axis=0, keepdims=True) / n

adj_resid = (obs - exp) / np.sqrt(exp * (1 - row_prop) * (1 - col_prop))
adj_resid_df = pd.DataFrame(
    adj_resid,
    index=contingency.index,
    columns=contingency.columns
)

# two-sided p-values from adjusted residuals
cell_p = 2 * (1 - norm.cdf(np.abs(adj_resid)))
cell_p_fdr = multipletests(cell_p.ravel(), method='fdr_bh')[1].reshape(cell_p.shape)

cell_p_df = pd.DataFrame(cell_p, index=contingency.index, columns=contingency.columns)
cell_p_fdr_df = pd.DataFrame(cell_p_fdr, index=contingency.index, columns=contingency.columns)

print("\nAdjusted standardized residuals:")
print(adj_resid_df.round(3))

print("\nCell-wise raw p-values:")
print(cell_p_df.round(4))

print("\nCell-wise FDR-adjusted p-values:")
print(cell_p_fdr_df.round(4))

# =========================================================
# 8. pre-specified 2x2 Fisher tests
# =========================================================
def one_vs_rest_fisher(contingency_df, target_row, target_col):
    a = contingency_df.loc[target_row, target_col]
    b = contingency_df.loc[target_row].sum() - a
    c = contingency_df[target_col].sum() - a
    d = contingency_df.values.sum() - a - b - c

    table_2x2 = np.array([
        [a, b],
        [c, d]
    ])

    oddsratio, p = fisher_exact(table_2x2, alternative='two-sided')
    return table_2x2, oddsratio, p

fisher_results = []
for target_row, target_col in pre_specified_tests:
    table_2x2, oddsratio, p = one_vs_rest_fisher(contingency, target_row, target_col)
    fisher_results.append({
        'MPRA_CRE_Cluster': target_row,
        'ATAC_CRE_Cluster': target_col,
        'a_target_target': table_2x2[0, 0],
        'b_target_othercols': table_2x2[0, 1],
        'c_otherrows_targetcol': table_2x2[1, 0],
        'd_otherrows_othercols': table_2x2[1, 1],
        'odds_ratio': oddsratio,
        'p_value': p
    })

fisher_results_df = pd.DataFrame(fisher_results)

if not fisher_results_df.empty:
    fisher_results_df['fdr_bh'] = multipletests(
        fisher_results_df['p_value'],
        method='fdr_bh'
    )[1]

print("\nPre-specified Fisher exact tests:")
print(fisher_results_df.round(4))

# save test tables
contingency.to_csv('contingency_table.csv')
expected_df.to_csv('expected_table.csv')
obs_over_exp.to_csv('observed_over_expected.csv')
adj_resid_df.to_csv('adjusted_standardized_residuals.csv')
cell_p_df.to_csv('cellwise_raw_pvalues.csv')
cell_p_fdr_df.to_csv('cellwise_fdr_pvalues.csv')
fisher_results_df.to_csv('prespecified_fisher_results.csv', index=False)

# =========================================================
# 9. plotting helper
# =========================================================
sns.set(style="white", context="paper")

def add_sig_stars_from_fdr(ax, fdr_df, thresholds=(0.05, 0.01, 0.001), fontsize=14):
    for i in range(fdr_df.shape[0]):
        for j in range(fdr_df.shape[1]):
            p = fdr_df.iloc[i, j]
            stars = ''
            if p < thresholds[2]:
                stars = '***'
            elif p < thresholds[1]:
                stars = '**'
            elif p < thresholds[0]:
                stars = '*'

            if stars:
                ax.text(
                    j + 0.5, i + 0.82, stars,
                    ha='center', va='center',
                    fontsize=fontsize, color='black'
                )

# =========================================================
# 10. plot observed/expected heatmap
# =========================================================
fig, ax = plt.subplots(figsize=(8.2, 6.2), dpi=300)

hm = sns.heatmap(
    obs_over_exp,
    cmap='RdBu_r',
    center=1.0,
    annot=True,
    fmt='.2f',
    linewidths=0,
    cbar=True,
    annot_kws={'fontsize': 16},
    ax=ax
)

ax.set_xlabel('ATAC CRE Cluster', fontsize=20, labelpad=12)
ax.set_ylabel('MPRA CRE Cluster', fontsize=20, labelpad=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=35, ha='right', fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(), rotation=90, va='center', fontsize=16)

ax.set_title(
    f'Observed / Expected\n'
    f'Chi-square p = {pval_chi2:.3g}; permutation p = {pval_perm:.3g}',
    fontsize=20,
    pad=14
)

ax.tick_params(
    axis='both',
    which='both',
    direction='out',
    length=6,
    width=1.5,
    labelsize=15
)

cbar = hm.collections[0].colorbar
cbar.ax.tick_params(labelsize=14, width=1.2, length=5)
cbar.ax.set_title('Observed\nExpected', fontsize=16, pad=14)

plt.tight_layout()
plt.savefig('obs_over_exp_heatmap.pdf', bbox_inches='tight')
plt.savefig('obs_over_exp_heatmap.svg', bbox_inches='tight')
plt.close()

# =========================================================
# 11. plot adjusted residual heatmap
# =========================================================
fig, ax = plt.subplots(figsize=(8.2, 6.2), dpi=300)

# 为了让正负偏离对称
vmax = np.ceil(np.max(np.abs(adj_resid_df.values)) * 10) / 10
vmin = -vmax

hm2 = sns.heatmap(
    adj_resid_df,
    cmap='RdBu_r',
    center=0,
    vmin=vmin,
    vmax=vmax,
    annot=True,
    fmt='.2f',
    linewidths=0,
    cbar=True,
    annot_kws={'fontsize': 16},
    ax=ax
)

add_sig_stars_from_fdr(ax, cell_p_fdr_df, fontsize=12)

ax.set_xlabel('ATAC CRE Cluster', fontsize=20, labelpad=12)
ax.set_ylabel('MPRA CRE Cluster', fontsize=20, labelpad=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=35, ha='right', fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(), rotation=90, va='center', fontsize=16)

ax.set_title(
    'Adjusted standardized residuals\n'
    '(* FDR < 0.05, ** FDR < 0.01, *** FDR < 0.001)',
    fontsize=18,
    pad=14
)

ax.tick_params(
    axis='both',
    which='both',
    direction='out',
    length=6,
    width=1.5,
    labelsize=15
)

cbar2 = hm2.collections[0].colorbar
cbar2.ax.tick_params(labelsize=14, width=1.2, length=5)
cbar2.ax.set_title('Adj.\nresid.', fontsize=16, pad=14)

plt.tight_layout()
plt.savefig('adjusted_residual_heatmap.pdf', bbox_inches='tight')
plt.savefig('adjusted_residual_heatmap.svg', bbox_inches='tight')
plt.close()

# =========================================================
# 12. optional: permutation null distribution plot
# =========================================================
fig, ax = plt.subplots(figsize=(6.2, 4.8), dpi=300)

ax.hist(chi2_perm_dist, bins=40, edgecolor='black')
ax.axvline(chi2_obs_perm, linestyle='--', linewidth=2)

ax.set_xlabel('Permuted chi-square statistic', fontsize=16)
ax.set_ylabel('Count', fontsize=16)
ax.set_title(f'Permutation test (p = {pval_perm:.3g})', fontsize=18, pad=12)

ax.tick_params(
    axis='both',
    which='both',
    direction='out',
    length=5,
    width=1.2,
    labelsize=13
)

plt.tight_layout()
plt.savefig('permutation_chi2_distribution.pdf', bbox_inches='tight')
plt.savefig('permutation_chi2_distribution.svg', bbox_inches='tight')
plt.close()

print("\nAll output files saved.")
# Out:
# Contingency table:
# col_0         Immune-enriched  Neuronal-enriched  Broad  Glial-enriched  \
# row_0
# Immune                     80                  3     41               3
# Brain                      55                 11     40               4
# Non-specific               16                  4     15               1
#
# col_0         Low-ATAC
# row_0
# Immune              22
# Brain               22
# Non-specific         3
#
# Expected table:
# col_0         Immune-enriched  Neuronal-enriched  Broad  Glial-enriched  \
# row_0
# Immune                 70.309              8.381   44.7           3.725
# Brain                  62.288              7.425   39.6           3.300
# Non-specific           18.403              2.194   11.7           0.975
#
# col_0         Low-ATAC
# row_0
# Immune          21.884
# Brain           19.388
# Non-specific     5.728
#
# Observed / Expected:
# col_0         Immune-enriched  Neuronal-enriched  Broad  Glial-enriched  \
# row_0
# Immune                  1.138              0.358  0.917           0.805
# Brain                   0.883              1.481  1.010           1.212
# Non-specific            0.869              1.823  1.282           1.026
#
# col_0         Low-ATAC
# row_0
# Immune           1.005
# Brain            1.135
# Non-specific     0.524
#
# Pearson chi-square:
#   chi2 = 12.3489
#   dof  = 8
#   p    = 0.1363
#
# G-test:
#   G    = 13.1599
#   dof  = 8
#   p    = 0.1065
#
# Cramer's V = 0.1389
#
# Permutation chi-square:
#   observed chi2 = 12.3489
#   p_perm        = 0.1322
#
# Adjusted standardized residuals:
# col_0         Immune-enriched  Neuronal-enriched  Broad  Glial-enriched  \
# row_0
# Immune                  2.175             -2.617 -0.905          -0.520
# Brain                  -1.658              1.762  0.099           0.509
# Non-specific           -0.823              1.340  1.231           0.027
#
# col_0         Low-ATAC
# row_0
# Immune           0.037
# Brain            0.838
# Non-specific    -1.317
#
# Cell-wise raw p-values:
# col_0         Immune-enriched  Neuronal-enriched   Broad  Glial-enriched  \
# row_0
# Immune                 0.0296             0.0089  0.3655          0.6028
# Brain                  0.0974             0.0781  0.9210          0.6107
# Non-specific           0.4107             0.1804  0.2185          0.9782
#
# col_0         Low-ATAC
# row_0
# Immune          0.9708
# Brain           0.4020
# Non-specific    0.1879
#
# Cell-wise FDR-adjusted p-values:
# col_0         Immune-enriched  Neuronal-enriched   Broad  Glial-enriched  \
# row_0
# Immune                 0.2220             0.1329  0.6161          0.7633
# Brain                  0.3652             0.3652  0.9782          0.7633
# Non-specific           0.6161             0.4682  0.4682          0.9782
#
# col_0         Low-ATAC
# row_0
# Immune          0.9782
# Brain           0.6161
# Non-specific    0.4682
#
# Pre-specified Fisher exact tests:
#   MPRA_CRE_Cluster   ATAC_CRE_Cluster  a_target_target  b_target_othercols  \
# 0           Immune    Immune-enriched               80                  69
# 1            Brain  Neuronal-enriched               11                 121
# 2            Brain     Glial-enriched                4                 128
#
#    c_otherrows_targetcol  d_otherrows_othercols  odds_ratio  p_value  fdr_bh
# 0                     71                    100      1.6330   0.0332  0.0996
# 1                      7                    181      2.3506   0.0886  0.1329
# 2                      4                    184      1.4375   0.7217  0.7217
#
# All output files saved.
