# %%
import pandas as pd

def process_dataframe(file_path1, file_path2, output_file):
    # Load data from CSV files
    df1 = pd.read_csv(file_path1, index_col=0)
    df2 = pd.read_csv(file_path2, index_col=0)
    
    # Merge the dataframes on index
    df = pd.merge(df1, df2, left_index=True, right_index=True)
    
    # Drop columns ending with numbers from 16 to 32
    cols_to_drop = [col for col in df.columns if any(col.endswith(str(n)) for n in range(16, 33))]
    df = df.drop(columns=cols_to_drop)
    
    # Identify indices containing "motifdisrupt"
    indices_to_drop = [idx for idx in df.index if "motifdisrupt" in idx]
    
    # Drop the identified indices
    df = df.drop(index=indices_to_drop)
    
    # Save the cleaned dataframe to a new CSV file
    df.to_csv(output_file)

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNGvsNaive_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNGvsNaive_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/THP1_LPSIFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_Naive_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_LPSIFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/THP1_LPSIFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_Naive_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_LPSIFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_THP1_IFNGvsNaive_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_THP1_IFNGvsNaive_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/THP1_IFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_Naive_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_IFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/THP1_IFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_Naive_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_IFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_THP1_IFNBvsNaive_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_THP1_IFNBvsNaive_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/THP1_IFNB_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_Naive_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_IFNBvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/THP1_IFNB_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_Naive_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_IFNBvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNGvsIFNG_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNGvsIFNG_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/THP1_LPSIFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_IFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_LPSIFNGvsIFNG_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/THP1_LPSIFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_IFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1_LPSIFNGvsIFNG_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_THP1Macrophage_barcodesBrainR1R2merged20240404.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/THP1MacrophageBrainR1R2merged20240404_RNA_matched_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/THP1MacrophagePseudobarcodes_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/BrainR1R2merged20240404_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1MacrophagevsBrainR1R2merged20240404_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/THP1MacrophagePseudobarcodes_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/BrainR1R2merged20240404_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/THP1MacrophagevsBrainR1R2merged20240404_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %% [markdown]
# # Brain THP1 differential

# %%
import pandas as pd
df = pd.read_csv( '/media/zihengc/T7/mpra3_lib_analysis/annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_HippocampusvsCortex_barcodes.csv' ,index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("/media/zihengc/T7/mpra3_lib_analysis/annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_HippocampusvsCortex_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/BrainR1R2merged20240404_Hippocampus_RNA_matched_barcodes_reshaped_altref.csv",
                  "Read_counts_R1R2/BrainR1R2merged20240404_Cortex_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/BrainR1R2merged20240404_HippocampusvsCortex_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/BrainR1R2merged20240404_Hippocampus_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/BrainR1R2merged20240404_Cortex_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/BrainR1R2merged20240404_HippocampusvsCortex_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/THP1MacrophagevsBrainR1R2merged20240404_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1MacrophagevsBrainR1R2merged20240404_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/THP1MacrophageBrainR1R2merged20240404_RNA_matched_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Parent,
                          rnaDesign = ~ Parent,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240814_comparative_THP1MacrophagevsBrainR1R2merged20240404_DifferentialEnhancer.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_HippocampusvsCortex_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/BrainR1R2merged20240404_HippocampusvsCortex_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_BrainR1R2merged20240404_HippocampusvsCortex_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ Hippocampus,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                             
res <-testLrt(obj)              

write.csv(res,"20240814_comparative_BrainR1R2merged20240404_HippocampusvsCortex_DifferentialEnhancer.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 1
# Timestamp: 2025-05-18 16:27:59.916486
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  12.704   0.442  13.704
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6183032 330.3   11848957 632.9  9053162 483.5
# Vcells 11140423  85.0   18628805 142.2 15589277 119.0
#
# Log messages:
# INFO [2025-05-18 16:27:46] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 13
# Timestamp: 2025-05-18 16:28:01.66928
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  15.250   0.370  15.761
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6184563 330.3   11848957 632.9  9053162 483.5
# Vcells 11146041  85.1   18628805 142.2 15589277 119.0
#
# Log messages:
# INFO [2025-05-18 16:27:45] loading futile.logger package
#
# stderr and stdout:
#
#
# ...

# %% [markdown]
# # THP1 Stimulation Differential Enhancer

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/THP1_LPSIFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_LPSIFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNGvsNaive_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ Tissue,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240626_comparative_THP1_LPSIFNGvsNaive_DifferentialEnhancer_tissue.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/THP1_IFNBvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_IFNBvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_IFNBvsNaive_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ IFNB,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240626_comparative_THP1_IFNBvsNaive_DifferentialEnhancer.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/THP1_IFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_IFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_IFNGvsNaive_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ IFNG,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240626_comparative_THP1_IFNGvsNaive_DifferentialEnhancer.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/THP1_LPSIFNGvsIFNG_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/THP1_LPSIFNGvsIFNG_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_THP1_LPSIFNGvsIFNG_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ LPSIFNG,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240829_comparative_THP1_LPSIFNGvsIFNG_DifferentialEnhancer.csv")

# %% [markdown]
# # HMC3 State Differential

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNGvsNaive_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNGvsNaive_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/HMC3_LPSIFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_Naive_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_LPSIFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/HMC3_LPSIFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_Naive_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_LPSIFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_HMC3_IFNGvsNaive_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_HMC3_IFNGvsNaive_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/HMC3_IFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_Naive_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_IFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/HMC3_IFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_Naive_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_IFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_HMC3_IFNBvsNaive_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_HMC3_IFNBvsNaive_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/HMC3_IFNB_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_Naive_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_IFNBvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/HMC3_IFNB_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_Naive_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_IFNBvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
import pandas as pd
df = pd.read_csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNGvsIFNG_barcodes.csv",index_col=0)
# Drop columns ending with numbers from 16 to 32
rows_to_drop = [row for row in df.index if any(row.endswith(str(n)) for n in range(16, 33))]
rows_to_drop = rows_to_drop+[idx for idx in df.index if "REF" in idx]
df = df.drop(index=rows_to_drop)
df.to_csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNGvsIFNG_barcodes_altref.csv")


process_dataframe("read_counts_R1R2/HMC3_LPSIFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_IFNG_DNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_LPSIFNGvsIFNG_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

process_dataframe("read_counts_R1R2/HMC3_LPSIFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_IFNG_RNA_matched_barcodes_reshaped_altref.csv",
                  "read_counts_R1R2/HMC3_LPSIFNGvsIFNG_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/HMC3_IFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_IFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_IFNGvsNaive_barcodes_altref.csv", header=TRUE,row.names=1)
df_DNA <- df_DNA[, !grepl("ZC23", colnames(df_DNA))]
df_RNA <- df_RNA[, !grepl("ZC23", colnames(df_RNA))]
annot_DNA <- annot_DNA[!grepl("ZC23", rownames(annot_DNA)), ]

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)


#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}


obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ IFNG,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240814_comparative_HMC3_IFNGvsNaive_DifferentialEnhancer.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/HMC3_IFNBvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_IFNBvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_IFNBvsNaive_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ IFNB,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240814_comparative_HMC3_IFNBvsNaive_DifferentialEnhancer.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/HMC3_LPSIFNGvsNaive_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_LPSIFNGvsNaive_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNGvsNaive_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ LPSIFNG,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240814_comparative_HMC3_LPSIFNGvsNaive_DifferentialEnhancer.csv")

# %%
#if (!require("BiocManager", quietly = TRUE))
    #install.packages("BiocManager")

#BiocManager::install("MPRAnalyze")
#Format the data into MPRA project
library("MPRAnalyze")
library("BiocParallel")
library("parallel")
dropEnhancer <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$enhancer_id	
    df <- df_RNA[ , !(names(df_RNA) %in% c("enhancer_id"))]
    return(df)
    }

dropX <- function(df_RNA){
    row.names(df_RNA) <-df_RNA$X
    df <- df_RNA[ , !(names(df_RNA) %in% c("X"))]
    return(df)
    }

num_cores <- detectCores()
register(MulticoreParam(num_cores-1))
bpparam <- MulticoreParam(num_cores-1, log = TRUE, stop.on.error = FALSE)

df_DNA <- read.csv("read_counts_R1R2/HMC3_LPSIFNGvsIFNG_DNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)
df_RNA <- read.csv("read_counts_R1R2/HMC3_LPSIFNGvsIFNG_RNA_matched_barcodes_reshaped_altref_alleleOnly.csv", header=TRUE,row.names=1)

df_DNA<-as.matrix(df_DNA)
df_RNA<-as.matrix(df_RNA)

annot_DNA <-read.csv("annotation_barcodes/mpra3_annot_HMC3_LPSIFNGvsIFNG_barcodes_altref.csv", header=TRUE,row.names=1)
#Format the columns as factor that is recognized by MPRAnalyze
for (i in colnames(annot_DNA)){
    annot_DNA[i] <- as.factor(annot_DNA[,i])
}

obj <- MpraObject(dnaCounts=df_DNA,
                  rnaCounts=df_RNA,
                  colAnnot=annot_DNA,
                  #control=control,
                  BPPARAM = bpparam
                  )
#Comparative analysisl; Tissue only
obj <- estimateDepthFactors(obj, lib.factor = c("Test"), which.lib = "both",depth.estimator = "uq")   
obj <- analyzeComparative(obj = obj, 
                          dnaDesign = ~ Barcode_number + Test,
                          rnaDesign = ~ LPSIFNG,
                          reducedDesign = ~ 1,
                          #mode="scale"
                          )                      
res <-testLrt(obj)              

write.csv(res,"20240814_comparative_HMC3_LPSIFNGvsIFNG_DifferentialEnhancer.csv")
# Out:
# Fitting model...
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 1
# Timestamp: 2025-05-18 15:59:58.805905
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  42.497   0.321  44.502
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6165799 329.3   11623812 620.8  7557427 403.7
# Vcells 11376472  86.8   19180781 146.4 19180754 146.4
#
# Log messages:
# INFO [2025-05-18 15:59:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 5
# Timestamp: 2025-05-18 16:00:06.888999
# Success: TRUE
#
# Task duration:
#    user  system elapsed
#  50.420   0.393  52.695
#
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  6167339 329.4   11623812 620.8  7557427 403.7
# Vcells 11382601  86.9   19180781 146.4 19180754 146.4
#
# Log messages:
# INFO [2025-05-18 15:59:14] loading futile.logger package
#
# stderr and stdout:
#
#
# ...
